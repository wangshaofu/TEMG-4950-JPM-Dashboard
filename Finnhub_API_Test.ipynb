# %%
import json
import requests
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import pipeline
import openai
import torch
import finnhub

# %%
# API config
finnhub_api_key = 'cl6b0r1r01ql8jir6omgcl6b0r1r01ql8jir6on0'
finnhub_client = finnhub.Client(api_key=finnhub_api_key)

# %%
result = finnhub_client.general_news('general')
result
# Out:
# [{'category': 'top news',
#   'datetime': 1699524300,
#   'headline': ': AstraZeneca hikes earnings forecast as surging cancer drug sales offset plunging revenue from COVID vaccines',
#   'id': 7317699,
#   'image': 'https://images.mktw.net/im-884166/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'AstraZeneca shares jumped 3% after the Anglo-Swedish drugmaker said it expects its full-year revenues will increase at a higher rate than previously forecast',
#   'url': 'https://www.marketwatch.com/story/astrazeneca-hikes-earnings-forecast-as-surging-cancer-drug-sales-offset-plunging-revenue-from-covid-vaccines-446bf363'},
#  {'category': 'top news',
#   'datetime': 1699524120,
#   'headline': 'Kelley Blue Book: The 2024 Acura MDX review: Pricing, tech and more for this poised, midsize luxury SUV',
#   'id': 7317700,
#   'image': 'https://images.mktw.net/im-880582/horizontal',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Quality, ability, and attractive pricing make the 2024 Acura MDX a must-consider for anyone planning to buy a new midsize 3-row luxury SUV.',
#   'url': 'https://www.marketwatch.com/story/the-2024-acura-mdx-review-pricing-tech-and-more-for-this-poised-midsize-luxury-suv-79a49906'},
#  {'category': 'top news',
#   'datetime': 1699524060,
#   'headline': 'Next Avenue: I want to believe we can travel together again, but we are aging at a different pace',
#   'id': 7317701,
#   'image': 'https://images.mktw.net/im-880373/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "My husband and I used to travel together with ease, but now I'm going without him. The difference in our tempos is impossible to ignore.",
#   'url': 'https://www.marketwatch.com/story/i-want-to-believe-we-can-travel-together-again-but-we-are-aging-at-a-different-pace-5368176e'},
#  {'category': 'top news',
#   'datetime': 1699524000,
#   'headline': 'NerdWallet: This is what travelers want more than perks',
#   'id': 7317702,
#   'image': 'https://images.mktw.net/im-834544/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'When it comes to fees, perks, flexibility and customer support, here’s what travelers prioritized in a recent survey.',
#   'url': 'https://www.marketwatch.com/story/this-is-what-travelers-want-more-than-perks-79a19204'},
#  {'category': 'top news',
#   'datetime': 1699523220,
#   'headline': 'Market Snapshot: S&P 500 futures struggle to extend eight-day winning streak ahead of Powell comments',
#   'id': 7317703,
#   'image': 'https://images.mktw.net/im-884160/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'U.S. stock futures were mixed as benchmark bond yields hovered near six-week lows and traders awaited comments from Fed Chair Jay Powell',
#   'url': 'https://www.marketwatch.com/story/s-p-500-futures-struggle-to-extend-eight-day-winning-streak-ahead-of-powell-comments-c03c36a0'},
#  {'category': 'top news',
#   'datetime': 1699521840,
#   'headline': ': FanDuel parent planning NYSE listing early next year',
#   'id': 7317704,
#   'image': 'https://images.mktw.net/im-774751/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'The parent company of FanDuel plans to list in the U.S. early next year, as Flutter Entertainment shares slumped on a profit warning.',
#   'url': 'https://www.marketwatch.com/story/fanduel-parent-planning-nyse-listing-early-next-year-0ae80f93'},
#  {'category': 'top news',
#   'datetime': 1699517280,
#   'headline': ': Nvidia reportedly launching chips for China market',
#   'id': 7317672,
#   'image': 'https://images.mktw.net/im-884154/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Nvidia is reportedly launching three microchips specifically for China, after getting blocked by the U.S. government from selling high-end chips there.',
#   'url': 'https://www.marketwatch.com/story/nvidia-reportedly-launching-chips-for-china-market-5345a3c9'},
#  {'category': 'top news',
#   'datetime': 1699501560,
#   'headline': ': Republican debate recap: Nikki Haley and Vivek Ramaswamy spar over heels and TikTok, Ron DeSantis blasts the Fed',
#   'id': 7317626,
#   'image': 'https://images.mktw.net/im-884090/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'If you missed the third Republican presidential primary debate, these are the viral moments everyone will be talking about.',
#   'url': 'https://www.marketwatch.com/story/republican-debate-recap-nikki-haley-and-vivek-ramaswamy-spar-over-heels-and-tiktok-ron-desantis-blasts-the-fed-5683ff89'},
#  {'category': 'top news',
#   'datetime': 1699500360,
#   'headline': ': Haley, Christie open to raising Social Security retirement age',
#   'id': 7317618,
#   'image': 'https://images.mktw.net/im-884112/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Candidates dodged specific ages but said younger people may face a higher retirement age',
#   'url': 'https://www.marketwatch.com/story/haley-christie-open-to-raising-social-security-retirement-age-2721ff1c'},
#  {'category': 'top news',
#   'datetime': 1699499700,
#   'headline': 'Key Words: ‘Rich people should not be collecting Social Security,’ Chris Christie says at GOP debate',
#   'id': 7317619,
#   'image': 'https://images.mktw.net/im-884104/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Former New Jersey Gov. Chris Christie had a message for Warren Buffett and anyone else considered ultra-wealthy: You’re wrong to claim Social Security benefits.',
#   'url': 'https://www.marketwatch.com/story/rich-people-should-not-be-collecting-social-security-chris-christie-says-at-gop-debate-4701ced4'},
#  {'category': 'top news',
#   'datetime': 1699499040,
#   'headline': ': DeSantis promises to ‘rein in’ the Fed to fight inflation, as Scott says he’d bring back Keystone XL pipeline',
#   'id': 7317620,
#   'image': 'https://images.mktw.net/im-884098/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "The participants in Wednesday night's Republican presidential debate offered proposals for addressing inflation.",
#   'url': 'https://www.marketwatch.com/story/desantis-promises-to-rein-in-the-fed-to-fight-inflation-as-scott-says-hed-bring-back-keystone-xl-pipeline-7d438a4a'},
#  {'category': 'top news',
#   'datetime': 1699497000,
#   'headline': 'Dow Jones Newswires: China’s consumer prices fall in October',
#   'id': 7317611,
#   'image': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "China's consumer prices fell in October, signaling weakness in domestic demand, according to official data.",
#   'url': 'https://www.marketwatch.com/story/china-s-consumer-prices-fell-in-october-5762832d'},
#  {'category': 'top news',
#   'datetime': 1699495320,
#   'headline': 'MarketWatch First Take: Disney CEO Bob Iger is getting his hands dirty as he focuses on studio woes — will be it enough?',
#   'id': 7317612,
#   'image': 'https://images.mktw.net/im-881106/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Walt Disney Co. Chief Executive Bob Iger appears to be making good progress in his turnaround efforts at the Magic Kingdom, and is now getting his hands dirty to fix the content problem at its studios.',
#   'url': 'https://www.marketwatch.com/story/disney-ceo-bob-iger-is-getting-his-hands-dirty-as-he-focuses-on-studio-woes-will-be-it-enough-703ae645'},
#  {'category': 'top news',
#   'datetime': 1699494540,
#   'headline': 'Key Words: ‘We’ve become a party of losers’: Vivek Ramaswamy blasts GOP ‘establishment’ in Miami debate',
#   'id': 7317613,
#   'image': 'https://images.mktw.net/im-884064/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Republican presidential hopeful Vivek Ramaswamy on Wednesday night slammed what he called the GOP "establishment," blaming it for Democrats\' wins in elections on Tuesday.',
#   'url': 'https://www.marketwatch.com/story/weve-become-a-party-of-losers-vivek-ramaswamy-blasts-gop-establishment-in-miami-debate-dccdf5df'},
#  {'category': 'top news',
#   'datetime': 1699494480,
#   'headline': 'Key Words: Nikki Haley stomps on Vivek Ramaswamy’s ‘3-inch heels’ comment during Republican debate',
#   'id': 7317607,
#   'image': 'https://images.mktw.net/im-884066/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'After Ramaswamy called Haley and DeSantis "Dick Cheney in 3-inch heels" during the third GOP debate, Haley was quick to hit back.',
#   'url': 'https://www.marketwatch.com/story/nikki-haley-stomps-on-vivek-ramaswamys-3-inch-heels-comment-during-republican-debate-1b0d9dd2'},
#  {'category': 'top news',
#   'datetime': 1699494120,
#   'headline': ': DeSantis blasts Trump for not having Mexico pay for border wall, while Haley says 45th president ‘put us $8 trillion in debt’',
#   'id': 7317608,
#   'image': 'https://images.mktw.net/im-884065/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'The top Republican challengers to Donald Trump went after him at their debate Wednesday night in Miami.',
#   'url': 'https://www.marketwatch.com/story/desantis-blasts-trump-for-not-having-mexico-pay-for-border-wall-while-haley-says-45th-president-put-us-8-trillion-in-debt-c19a3052'},
#  {'category': 'top news',
#   'datetime': 1699491130,
#   'headline': "SAG-AFTRA actors' union reaches tentative labor agreement with Hollywood studios",
#   'id': 7317594,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107321053-16978274002023-10-20t183427z_521910842_rc2iw3a3xdkw_rtrmadp_0_television-actors-100-days.jpeg?v=1697827449&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': "Hollywood's actors and studios have a preliminary labor agreement.",
#   'url': 'https://www.cnbc.com/2023/11/08/sag-aftra-actors-union-reaches-tentative-labor-agreement-with-hollywood-studios.html'},
#  {'category': 'top news',
#   'datetime': 1699489380,
#   'headline': 'Dow Jones Newswires: Tyson Foods to close two plants as it keeps cutting costs',
#   'id': 7317592,
#   'image': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Tyson Foods is closing two of its smaller case ready meat facilities as it continues to cut costs.',
#   'url': 'https://www.marketwatch.com/story/tyson-foods-to-close-two-plants-as-it-keeps-cutting-costs-2441fd89'},
#  {'category': 'top news',
#   'datetime': 1699489320,
#   'headline': 'Dow Jones Newswires: Takeda says FDA approves its treatment for colorectal cancer',
#   'id': 7317593,
#   'image': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Pharmaceutical company Takeda said Wednesday that the U.S. Food and Drug Administration approved Fruzaqla as a treatment for certain patients with colorectal cancer.',
#   'url': 'https://www.marketwatch.com/story/takeda-says-fda-approves-treatment-for-colorectal-cancer-169976d2'},
#  {'category': 'top news',
#   'datetime': 1699487606,
#   'headline': 'Snap conducts a small round of layoffs to its product team',
#   'id': 7317583,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107226136-16817336462022-06-17t140805z_1495950499_rc2otu9v0htc_rtrmadp_0_france-tech.jpeg?v=1697487030&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'Snap has conducted a round of layoffs impacting 20 product managers as part of a reorganization intended to streamline the social-messaging company.',
#   'url': 'https://www.cnbc.com/2023/11/08/snap-conducts-a-small-round-of-layoffs-to-its-product-team.html'},
#  {'category': 'top news',
#   'datetime': 1699486320,
#   'headline': 'The Fed: Goldman’s chief economist downplays recession fears from past Fed rate hikes',
#   'id': 7317582,
#   'image': 'https://images.mktw.net/im-832046/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Goldman's chief economist, Jan Hatzius, thinks the negative effect of the Fed's rapid rate hikes on economic growth is already behind us.",
#   'url': 'https://www.marketwatch.com/story/goldmans-chief-economist-downplays-recession-fears-from-past-fed-rate-hikes-f1e5f56b'},
#  {'category': 'business',
#   'datetime': 1699482974,
#   'headline': "ESPN shows strength as Disney's other networks report lower revenue",
#   'id': 7317563,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107287747-1692217295114-gettyimages-1166897541-20190908_bw_nyy_pg_06.jpeg?v=1692217399&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': "ESPN's operating income and revenue should come as a giant relief to investors.",
#   'url': 'https://www.cnbc.com/2023/11/08/espn-shows-strength-in-disney-earnings.html'},
#  {'category': 'top news',
#   'datetime': 1699482660,
#   'headline': 'Earnings Results: Virgin Galactic’s stock soars, company rakes in nearly $2 million in revenue from space tourism',
#   'id': 7317572,
#   'image': 'https://images.mktw.net/im-810079/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Virgin Galactic narrowed its quarterly loss and more than doubled its revenue.',
#   'url': 'https://www.marketwatch.com/story/virgin-galactics-stock-soars-after-company-rakes-up-1-7-million-in-revenue-from-space-tourism-f4a4706c'},
#  {'category': 'top news',
#   'datetime': 1699481700,
#   'headline': 'The Tell: Mutual funds that buy U.S. stocks just had their best ‘hit rate’ in two years, BofA says',
#   'id': 7317555,
#   'image': 'https://images.mktw.net/im-783331/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Managers of mutual funds focused on large-cap stocks in the U.S. did a stronger job of beating their benchmark last month, but they’re still struggling to do so year to date, according to BofA Global Research.',
#   'url': 'https://www.marketwatch.com/story/mutual-funds-that-buy-u-s-stocks-just-had-their-best-hit-rate-in-two-years-bofa-says-ad6a7285'},
#  {'category': 'top news',
#   'datetime': 1699480920,
#   'headline': "Brett Arends's ROI: Beware Wall Street’s ‘cash on the sidelines’ myth",
#   'id': 7317556,
#   'image': 'https://images.mktw.net/im-883822/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Wall Street is once again pushing the feel-good theory that there is a giant wave of money just waiting to come into the stock market and drive stock prices higher.',
#   'url': 'https://www.marketwatch.com/story/beware-wall-streets-cash-on-the-sidelines-myth-6821fa94'},
#  {'category': 'top news',
#   'datetime': 1699480080,
#   'headline': 'Earnings Results: Arm’s first earnings report since IPO comes with a disappointing forecast',
#   'id': 7317557,
#   'image': 'https://images.mktw.net/im-839575/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Arm shares were headed lower in Wednesday's late trading as the company's outlook missed the mark at the midpoint.",
#   'url': 'https://www.marketwatch.com/story/arms-first-earnings-report-since-ipo-comes-with-a-disappointing-forecast-a73c8605'},
#  {'category': 'top news',
#   'datetime': 1699479840,
#   'headline': 'Earnings Results: Instacart reports a $2 billion loss, but sales that beat expectations',
#   'id': 7317558,
#   'image': 'https://images.mktw.net/im-883551/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Grocery-delivery platform Instacart on Wednesday reported a nearly $2 billion loss in its first earnings report since going public, but its sales beat expectations and the company forecast "mid-single-digit" growth in the total value of transactions on its platform.',
#   'url': 'https://www.marketwatch.com/story/instacart-reports-a-2-billion-loss-but-sales-that-beat-expectations-fef990a1'},
#  {'category': 'top news',
#   'datetime': 1699479180,
#   'headline': 'Earnings Results: Applovin’s stock rockets as earnings easily exceed expectations',
#   'id': 7317526,
#   'image': 'https://images.mktw.net/im-833362/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'The app-monetization company blew past expectations with its latest quarterly results.',
#   'url': 'https://www.marketwatch.com/story/applovins-stock-rockets-as-earnings-easily-exceed-expectations-8443c389'},
#  {'category': 'top news',
#   'datetime': 1699479000,
#   'headline': ': Putin signs decree to swap foreigners’ assets frozen in Russia for Russian assets blocked overseas',
#   'id': 7317527,
#   'image': 'https://images.mktw.net/im-883890/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Russia has faced a wave of international sanctions following its 2022 invasion of Ukraine.',
#   'url': 'https://www.marketwatch.com/story/putin-signs-decree-to-swap-foreigners-assets-frozen-in-russia-for-russian-assets-blocked-overseas-bb68a1c1'},
#  {'category': 'top news',
#   'datetime': 1699478880,
#   'headline': 'The Tell: Nobody on Wall Street wants to bet against the ‘Magnificent Seven’',
#   'id': 7317528,
#   'image': 'https://images.mktw.net/im-840253/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Almost nobody on Wall Street has the temerity to bet against the "Magnificent Seven" group of tech stocks.',
#   'url': 'https://www.marketwatch.com/story/nobody-on-wall-street-wants-to-bet-against-the-magnificent-seven-62513e47'},
#  {'category': 'top news',
#   'datetime': 1699478700,
#   'headline': 'Earnings Results: Disney shares rise on huge increase in streaming users, improved earnings',
#   'id': 7317529,
#   'image': 'https://images.mktw.net/im-810420/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Walt Disney Co.'s stock edged up 2% in extended trading Wednesday after the media giant announced earnings that beat estimates, a huge jump in streaming users, and a vow to increase its annual efficiency cost reductions to $7.5 billion from $5.5 billion.",
#   'url': 'https://www.marketwatch.com/story/disney-shares-rise-on-huge-increase-in-streaming-users-improved-earnings-1299f071'},
#  {'category': 'top news',
#   'datetime': 1699478520,
#   'headline': 'Earnings Results: Affirm’s stock pops after earnings bring narrowing loss, big revenue beat',
#   'id': 7317530,
#   'image': 'https://images.mktw.net/im-883806/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Affirm logged a big revenue beat for its latest quarter, and its shares were moving higher in the extended session after Wednesday's report.",
#   'url': 'https://www.marketwatch.com/story/affirms-stock-pops-after-earnings-bring-narrowing-loss-big-revenue-beat-2645be49'},
#  {'category': 'top news',
#   'datetime': 1699478400,
#   'headline': 'Earnings Results: Lyft results beat estimates, execs say big October gains have continued, but shares drop',
#   'id': 7317531,
#   'image': 'https://images.mktw.net/im-883483/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Lyft Inc. on Wednesday reported third-quarter results that beat Wall Street's estimates and forecast fourth-quarter sales growth that was better than expected, helped by growth in back-to-school-season demand and a push to send workers back to offices.",
#   'url': 'https://www.marketwatch.com/story/lyft-results-beat-estimates-execs-say-big-october-gains-have-continued-but-shares-drop-a77444be'},
#  {'category': 'top news',
#   'datetime': 1699478160,
#   'headline': 'Earnings Results: Warner Bros.’ stock on track for worst day in two years after warning about debt',
#   'id': 7317532,
#   'image': 'https://images.mktw.net/im-883865/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Warner Bros. says it won't meet 2024 debt-repayment goals if the TV ad market doesn't recover.",
#   'url': 'https://www.marketwatch.com/story/warner-bros-discovery-stock-slumps-after-wider-than-expected-loss-while-revenue-topped-projections-b48ec60d'},
#  {'category': 'top news',
#   'datetime': 1699472520,
#   'headline': ': Some $2 bills are worth more than $20,000 — here are three ways to check',
#   'id': 7317508,
#   'image': 'https://images.mktw.net/im-883737/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Your $2 bills could be worth over $20,000 — here’s 3 ways to check',
#   'url': 'https://www.marketwatch.com/story/your-2-bills-could-be-worth-over-20-000-heres-3-ways-to-check-4d7b942a'},
#  {'category': 'top news',
#   'datetime': 1699472386,
#   'headline': "Eli Lilly receives approval for its weight-loss drug. But here's what could boost the stock next",
#   'id': 7317495,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107261723-1687535077484-gettyimages-1302141489-cailly03.jpeg?v=1699466920&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': "Shares of Eli Lilly jumped Wednesday after the U.S. gave the green light for the company's blockbuster GLP-1 drug to be used as an obesity treatment.",
#   'url': 'https://www.cnbc.com/2023/11/08/this-could-be-the-next-catalyst-for-eli-lilly-stock-.html'},
#  {'category': 'top news',
#   'datetime': 1699472340,
#   'headline': 'Earnings Results: Warby Parker’s stock suffers record selloff as margins were hurt by contact lens sales strength',
#   'id': 7317509,
#   'image': 'https://images.mktw.net/im-883725/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Warby Parker's stock was having its worst day since going public two years ago, as strength in contact lens sales continued to weigh on profitability.",
#   'url': 'https://www.marketwatch.com/story/warby-parker-beats-revenue-expectations-and-boosts-full-year-outlook-as-contact-lens-sales-outperform-6e196b8d'},
#  {'category': 'business',
#   'datetime': 1699470896,
#   'headline': 'Caesars reaches deal with Las Vegas union to avoid strike',
#   'id': 7317493,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107259590-1687287812366-gettyimages-501800838-88584158.jpeg?v=1699471666&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'The agreement averts a walkout by 10,000 Caesars employees on the Las Vegas strip.',
#   'url': 'https://www.cnbc.com/2023/11/08/caesars-reaches-deal-with-las-vegas-union-to-avoid-strike.html'},
#  {'category': 'top news',
#   'datetime': 1699470600,
#   'headline': 'In One Chart: Credit-card, auto-loan ‘stress’ rises as U.S. consumers fall behind on payments',
#   'id': 7317489,
#   'image': 'https://images.mktw.net/im-880729/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Consumers are showing some signs of stress even as the unemployment rate — at least for now — remains historically low, according to Renaissance Macro Research.',
#   'url': 'https://www.marketwatch.com/story/credit-card-auto-loan-stress-rises-as-u-s-consumers-fall-behind-on-payments-e6629741'},
#  {'category': 'top news',
#   'datetime': 1699470539,
#   'headline': "This S&P 500 stock has the highest return over the past 20 years—it's not Apple or Tesla",
#   'id': 7317486,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107330423-1699391235430-gettyimages-1763923121-jeb13709_39bslose.jpeg?v=1699469987&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'Over the past two decades, no stock in the S&amp;P 500 has posted a higher return than energy drink firm Monster Beverage.',
#   'url': 'https://www.cnbc.com/2023/11/08/sp-500-stock-has-the-highest-return-over-the-past-20-years.html'},
#  {'category': 'top news',
#   'datetime': 1699470180,
#   'headline': ': Bank of America Chief Brian Moynihan doubles down on environmental goals, saying it’s what customers and the private sector want',
#   'id': 7317490,
#   'image': 'https://images.mktw.net/im-883589/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Bank of America Corp. Chief Executive Brian Moynihan doubled down on the bank's net-zero-emissions efforts despite pushback in the political arena.",
#   'url': 'https://www.marketwatch.com/story/bank-of-america-chief-kevin-moynihan-doubles-down-on-environmental-goals-saying-its-what-customers-and-the-private-sector-want-a1350349'},
#  {'category': 'top news',
#   'datetime': 1699469880,
#   'headline': 'In One Chart: The U.S. dollar has peaked — now it gets ‘messy’: SocGen',
#   'id': 7317491,
#   'image': 'https://images.mktw.net/im-847624/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "A peak for the U.S. dollar is in the rearview mirror, setting up a stretch of 'messy' market action, says SocGen.",
#   'url': 'https://www.marketwatch.com/story/the-u-s-dollar-has-peaked-now-it-gets-messy-socgen-29733deb'},
#  {'category': 'top news',
#   'datetime': 1699469400,
#   'headline': ': Airbnb is betting that greater transparency in listings will boost demand',
#   'id': 7317492,
#   'image': 'https://images.mktw.net/im-883617/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Airbnb is seeking to avert the disappointment of a home that looks nothing like the photos in the listing.',
#   'url': 'https://www.marketwatch.com/story/airbnb-to-revamp-ratings-and-reviews-and-other-features-to-help-guests-full-understand-quality-of-a-home-12c8993a'},
#  {'category': 'top news',
#   'datetime': 1699467720,
#   'headline': 'The Ratings Game: Rivian’s ‘daunting’ production ramp keeps investors cautious',
#   'id': 7317476,
#   'image': 'https://images.mktw.net/im-715334/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Rivian's earnings were 'heartening,' but there's a 'daunting ramp' just around the corner.",
#   'url': 'https://www.marketwatch.com/story/rivians-daunting-production-ramp-keeps-investors-cautious-6e66f575'},
#  {'category': 'top news',
#   'datetime': 1699467720,
#   'headline': ': Eli Lilly gets FDA approval for new obesity drug',
#   'id': 7317477,
#   'image': 'https://images.mktw.net/im-735118/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Zepbound helped patients lose up to 48 pounds on average in clinical trials.',
#   'url': 'https://www.marketwatch.com/story/eli-lilly-gets-fda-approval-for-new-obesity-drug-ef514794'},
#  {'category': 'top news',
#   'datetime': 1699467480,
#   'headline': 'Front Office Sports: Peacock, Comcast are using sports to turn a corner in the streaming battle',
#   'id': 7317478,
#   'image': 'https://images.mktw.net/im-291950/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': '',
#   'url': 'https://www.marketwatch.com/story/peacock-comcast-are-using-sports-to-turn-a-corner-in-the-streaming-battle-d49a645f'},
#  {'category': 'top news',
#   'datetime': 1699465620,
#   'headline': 'Market Extra: Market-based inflation expectations jump, adding to list of upside risks',
#   'id': 7317479,
#   'image': 'https://images.mktw.net/im-883497/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'A market-based measure of future inflation expectations is back near the top of its historical ranges, raising the possibility of more upside risks to price gains that could rattle financial markets.',
#   'url': 'https://www.marketwatch.com/story/market-based-inflation-expectations-jump-adding-to-list-of-upside-risks-3a940573'},
#  {'category': 'top news',
#   'datetime': 1699464657,
#   'headline': "Don't just press 'connect' when adding people on LinkedIn: 'All it shows is that you were able to push a button,' says expert",
#   'id': 7317460,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107330858-1699459532118-charming-young-woman-working-on-computer-portrait-2022-12-18-17-36-12-utc.jpg?v=1699459620&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': "LinkedIn offers a plethora opportunities to connect — but you want to do it the right way, say experts. Here's how.",
#   'url': 'https://www.cnbc.com/2023/11/08/never-just-click-the-connect-button-on-linkedin.html'},
#  {'category': 'top news',
#   'datetime': 1699464060,
#   'headline': 'The Tell: Stock-market timers beware: Just 8 days account for all of the S&P 500’s 14% gain in 2023',
#   'id': 7317458,
#   'image': 'https://images.mktw.net/im-883487/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': '',
#   'url': 'https://www.marketwatch.com/story/stock-market-timers-beware-just-8-days-account-for-all-of-the-s-p-500s-14-gain-in-2023-410e038e'},
#  {'category': 'business',
#   'datetime': 1699464036,
#   'headline': "FDA approves Eli Lilly's tirzepatide for obesity, paving way for even wider use of blockbuster drug",
#   'id': 7317455,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107277199-16903924192023-03-29t000000z_926919308_rc2w30aq63my_rtrmadp_0_usa-health.jpeg?v=1698956978&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'The obesity approval further establishes Eli Lilly as a formidable competitor to Novo Nordisk in the budding weight loss drug industry.',
#   'url': 'https://www.cnbc.com/2023/11/08/fda-approves-eli-lilly-drug-tirzepatide-for-obesity.html'},
#  {'category': 'top news',
#   'datetime': 1699461840,
#   'headline': ': The Supreme Court’s affirmative action decision won’t impact most college students this year',
#   'id': 7317459,
#   'image': 'https://images.mktw.net/im-883475/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'It still matters when it comes to who has access to the colleges that confer the most economic success and power',
#   'url': 'https://www.marketwatch.com/story/the-supreme-courts-affirmative-action-decision-wont-impact-most-college-students-this-year-5a11d000'},
#  {'category': 'top news',
#   'datetime': 1699460820,
#   'headline': ': 3 simple rules for collecting baseball cards, from one of the nicest guys The Hobby has ever known',
#   'id': 7317426,
#   'image': 'https://images.mktw.net/im-883061/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Blogger who died suddenly left behind 15 years of advice for card collectors, including 'This hobby isn’t just about money'",
#   'url': 'https://www.marketwatch.com/story/3-simple-rules-for-collecting-baseball-cards-from-one-of-the-nicest-guys-the-hobby-has-ever-known-fce322ab'},
#  {'category': 'top news',
#   'datetime': 1699460760,
#   'headline': 'The Fed: Cleveland Fed’s Mester to retire next June',
#   'id': 7317427,
#   'image': 'https://images.mktw.net/im-280561/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Loretta Mester will step down as the president of the Cleveland Federal Reserve in June 2024, the regional Fed bank announced Wednesday.',
#   'url': 'https://www.marketwatch.com/story/cleveland-feds-mester-to-retire-next-june-428ad7e0'},
#  {'category': 'top news',
#   'datetime': 1699460160,
#   'headline': 'Economic Report: Businesses take stock of the U.S. economy and see reason to be cautious',
#   'id': 7317428,
#   'image': 'https://images.mktw.net/im-865589/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'The level of inventories, or unsold goods, that wholesalers are keeping on hand fell in September to a 13-month low amid uncertainty about whether the economy can maintain its recent momentum.',
#   'url': 'https://www.marketwatch.com/story/businesses-take-stock-of-the-u-s-economy-and-see-reason-to-be-cautious-1ebc84fe'},
#  {'category': 'top news',
#   'datetime': 1699459920,
#   'headline': ': Americans’ support for legalizing cannabis edges up to 70% and Ohio voters OK pot referendum, as cannabis stocks rise',
#   'id': 7317429,
#   'image': 'https://images.mktw.net/im-883363/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Trulieve, Verano, Green Thumb Industries and Cresco Labs all posted solid gains.',
#   'url': 'https://www.marketwatch.com/story/american-support-for-marijuana-legalization-edges-up-to-70-from-68-74e2e267'},
#  {'category': 'top news',
#   'datetime': 1699459380,
#   'headline': 'Deep Dive: Three value stock picks from a veteran manager with a good performance record',
#   'id': 7317430,
#   'image': 'https://images.mktw.net/im-883394/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'John Bailer of Newton Investment Management names three companies whose stocks seem ripe for the plucking.',
#   'url': 'https://www.marketwatch.com/story/three-value-stock-picks-from-a-veteran-manager-with-a-good-performance-record-9cce6a0f'},
#  {'category': 'top news',
#   'datetime': 1699459020,
#   'headline': 'Earnings Results: Under Armour posts better-than-expected earnings, but no longer expects revenue to grow this year',
#   'id': 7317431,
#   'image': 'https://images.mktw.net/im-883391/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "The company said it's seeing softness in its wholesale future-orders book.",
#   'url': 'https://www.marketwatch.com/story/under-armour-tops-fiscal-second-quarter-estimates-but-lowers-full-year-revenue-outlook-12acf5ff'},
#  {'category': 'top news',
#   'datetime': 1699458660,
#   'headline': ': AMC earnings: What to expect from the movie-theater chain and meme-stock darling',
#   'id': 7317432,
#   'image': 'https://images.mktw.net/im-415422/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'AMC reports third-quarter results amid reports of improving box office results',
#   'url': 'https://www.marketwatch.com/story/amc-earnings-what-to-expect-from-the-movie-theater-chain-and-meme-stock-darling-4e31d1d8'},
#  {'category': 'top news',
#   'datetime': 1699458180,
#   'headline': 'Washington Watch: Election takeaways: Biden ‘didn’t stop Democrats from winning,’ while Youngkin was hit with ‘a stunning repudiation’',
#   'id': 7317433,
#   'image': 'https://images.mktw.net/im-883313/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "As analysts assess the results of Tuesday's off-year elections, they're concluding that the outcomes were disappointing for Republicans and for Virginia Gov. Glenn Younkin in particular.",
#   'url': 'https://www.marketwatch.com/story/election-takeaways-biden-didnt-stop-democrats-from-winning-while-youngkin-was-hit-with-a-stunning-repudiation-fbea8a77'},
#  {'category': 'top news',
#   'datetime': 1699457160,
#   'headline': ': EV maker Fisker’s stock falls toward a record low after sudden delay of earnings release',
#   'id': 7317402,
#   'image': 'https://images.mktw.net/im-883374/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Fisker's stock sank toward a record low Wednesday after the EV maker suddenly pushed back the release of its third-quarter results by nearly a week.",
#   'url': 'https://www.marketwatch.com/story/fiskers-stock-falls-toward-a-record-low-after-earnings-release-delayed-by-about-a-week-9acab318'},
#  {'category': 'top news',
#   'datetime': 1699456500,
#   'headline': 'Market Extra: ‘$4 trillion of cash is sloshing around the sidelines,’ says BlackRock exec. Here’s where he thinks that’s headed.',
#   'id': 7317403,
#   'image': 'https://images.mktw.net/im-883319/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Investor cash, and lots of it, is sitting on the sidelines, ready to be put to work, says the world's biggest asset manager.",
#   'url': 'https://www.marketwatch.com/story/4-trillion-of-cash-is-sloshing-around-the-sidelines-says-blackrock-exec-heres-where-he-thinks-thats-headed-5716a897'},
#  {'category': 'top news',
#   'datetime': 1699456380,
#   'headline': ': Half of Americans say their finances have worsened under Biden. Some are pointing fingers.',
#   'id': 7317404,
#   'image': 'https://images.mktw.net/im-882980/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'One year ahead of the 2024 presidential election, most Americans say the state of the economy will help determine their vote.',
#   'url': 'https://www.marketwatch.com/story/half-of-americans-say-their-finances-have-worsened-since-the-2020-election-some-blame-president-biden-1e2e1931'},
#  {'category': 'business',
#   'datetime': 1699456078,
#   'headline': 'Satellite imagery company BlackSky ekes out first quarterly profit',
#   'id': 7317392,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107204269-1678195880200-BlackSky_Inc-1437450717908725760-img1.jpg?v=1678195953&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'Satellite imagery venture BlackSky delivered its first quarterly profit on Wednesday, as the company works to keep up momentum into the end of the year.',
#   'url': 'https://www.cnbc.com/2023/11/08/satellite-imagery-blacksky-ekes-out-first-quarterly-profit.html'},
#  {'category': 'top news',
#   'datetime': 1699455180,
#   'headline': ': A third of home buyers are paying all cash as mortgage rates stay high, Redfin says',
#   'id': 7317405,
#   'image': 'https://images.mktw.net/im-883331/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Home buyers are increasingly paying all cash as mortgage rates remain elevated, according to a new report.',
#   'url': 'https://www.marketwatch.com/story/a-third-of-home-buyers-are-paying-all-cash-as-mortgage-rates-stay-high-redfin-says-a7869d2c'},
#  {'category': 'top news',
#   'datetime': 1699454427,
#   'headline': 'Maine votes to keep investor-owned electricity companies in charge of the energy grid',
#   'id': 7317389,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107330362-1699385470994-gettyimages-1238687850-6vv7vvgpzy3kbnr7q7yupdqyly.jpeg?v=1699385551&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'The push to create a publicly-owned power grid in Maine has been struck down multiple times in the past.',
#   'url': 'https://www.cnbc.com/2023/11/08/maine-votes-to-keep-investor-owned-electricity-companies.html'},
#  {'category': 'top news',
#   'datetime': 1699454312,
#   'headline': 'Robinhood shares drop 12% after reporting big declines in trading volume and revenue',
#   'id': 7317367,
#   'image': 'https://image.cnbcfm.com/api/v1/image/106918758-1627561538410-gettyimages-1234275430-AFP_9H42QN.jpeg?v=1699451712&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'Shares of Robinhood were lower Wednesday after the retail brokerage reported a drop in trading volumes in the last quarter.',
#   'url': 'https://www.cnbc.com/2023/11/08/robinhood-shares-drop-7percent-after-reporting-big-declines-trading-revenue.html'},
#  {'category': 'top news',
#   'datetime': 1699453200,
#   'headline': ': CFPB fines Citi $26 million for ‘intentional’ discrimination against Armenian Americans',
#   'id': 7317362,
#   'image': 'https://images.mktw.net/im-883323/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'The Consumer Financial Protection Bureau ordered Citibank to pay $25.9 million in fines and consumer redress for intentional and illegal discrimination against credit-card applicants based on their Armenian heritage.',
#   'url': 'https://www.marketwatch.com/story/cfpb-fines-citi-26-million-for-intentional-discrimination-against-armenian-americans-fd485d35'},
#  {'category': 'top news',
#   'datetime': 1699453080,
#   'headline': 'Banking: Goldman Sachs advises employees on plan to divest GM credit card',
#   'id': 7317363,
#   'image': 'https://images.mktw.net/im-883327/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Goldman Sachs advises employees on plan to divest GM credit card',
#   'url': 'https://www.marketwatch.com/story/goldman-sachs-advises-employees-on-plan-to-divest-gm-credit-card-05e10be6'},
#  {'category': 'top news',
#   'datetime': 1699452921,
#   'headline': "Jim Cramer's top 10 things to watch in the stock market Wednesday",
#   'id': 7317361,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107270447-1689176394217-DavidAGrogan_Photography__18_of_75.jpg?v=1689176749&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'Stock futures were flat Wednesday as the S&amp;P 500 and Nasdaq both looked to extend their longest winning streaks in two years.',
#   'url': 'https://www.cnbc.com/2023/11/08/jim-cramers-top-10-things-to-watch-in-the-stock-market-wednesday.html'},
#  {'category': 'top news',
#   'datetime': 1699452840,
#   'headline': ': From oil to crypto, AI chips and interest rates – these are the 13 policymakers who matter in markets',
#   'id': 7317364,
#   'image': 'https://images.mktw.net/im-871655/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': '',
#   'url': 'https://www.marketwatch.com/story/from-oil-to-crypto-ai-chips-and-interest-rates-these-are-the-13-policymakers-who-matter-in-markets-09ec28e1'},
#  {'category': 'top news',
#   'datetime': 1699452660,
#   'headline': 'The Ratings Game: Upstart’s stock could post worst day in a year as analysts see more pain ahead',
#   'id': 7317365,
#   'image': 'https://images.mktw.net/im-432651/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Analysts noted challenges related to loan demand and funding in the wake of Upstart's latest earnings.",
#   'url': 'https://www.marketwatch.com/story/upstarts-stock-could-post-worst-day-in-a-year-as-analysts-see-more-pain-ahead-7227b30e'},
#  {'category': 'top news',
#   'datetime': 1699451160,
#   'headline': ': Teva shares climb as third-quarter sales top estimates',
#   'id': 7317366,
#   'image': 'https://images.mktw.net/im-864901/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Production 'largely unaffected' Israel-Hamas war, drugmaker says",
#   'url': 'https://www.marketwatch.com/story/teva-shares-climb-as-third-quarter-sales-top-estimates-0643efdb'},
#  {'category': 'top news',
#   'datetime': 1699451044,
#   'headline': "Israeli forces in Gaza turn their focus to Hamas' infamous tunnel system",
#   'id': 7317343,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107317744-1697460595169-gettyimages-1546737195-Israeli-Palestinian_conflict_-_July_19_202311.jpeg?v=1699449310&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'The labyrinth of tunnels offer Hamas a strategic advantage to shield and ambush Israeli ground infantry, as well as move and store weapons and explosives.',
#   'url': 'https://www.cnbc.com/2023/11/08/israeli-forces-in-gaza-turn-their-focus-to-hamas-tunnel-system.html'},
#  {'category': 'top news',
#   'datetime': 1699449480,
#   'headline': 'Earnings Results: Roblox’s stock roars higher as losses narrow',
#   'id': 7317318,
#   'image': 'https://images.mktw.net/im-849632/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Roblox's stock roars higher as losses narrow",
#   'url': 'https://www.marketwatch.com/story/robloxs-stock-roars-higher-as-losses-narrow-eee220d9'},
#  {'category': 'top news',
#   'datetime': 1699448880,
#   'headline': 'Market Extra: What would a U.S. debt crisis look like? Citi economist answers most pressing questions about $26 trillion Treasury market.',
#   'id': 7317319,
#   'image': 'https://images.mktw.net/im-883306/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Volatility in the once-staid $25.7 trillion market for Treasury bonds has exploded this year, driven in part by doubts about investors' ability to absorb a deluge of expected supply.",
#   'url': 'https://www.marketwatch.com/story/what-would-a-u-s-debt-crisis-look-like-citi-economist-answers-most-pressing-questions-about-26-trillion-treasury-market-be443cc0'},
#  {'category': 'top news',
#   'datetime': 1699448280,
#   'headline': ': Bayer vows to cut ‘multiple layers of management’ by end of 2024 as new CEO says firm’s performance is ‘not acceptable’',
#   'id': 7317320,
#   'image': 'https://images.mktw.net/im-883304/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Bayer\'s new CEO Bill Anderson outlines plans to turn the pharma firm around after stating he is "not happy" with its performance',
#   'url': 'https://www.marketwatch.com/story/bayer-vows-to-cut-multiple-layers-of-management-by-end-of-2024-as-new-ceo-says-firms-performance-is-not-acceptable-3e05498a'},
#  {'category': 'top news',
#   'datetime': 1699446840,
#   'headline': 'Futures Movers: Oil extends slump after ending at lowest in more than 3 months',
#   'id': 7317321,
#   'image': 'https://images.mktw.net/im-637623/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Oil futures fall Wednesday, extending a retreat that took crude to its lowest close since late July in the previous session.',
#   'url': 'https://www.marketwatch.com/story/oil-extends-slump-after-ending-at-lowest-in-more-than-3-months-d4ed2133'},
#  {'category': 'top news',
#   'datetime': 1699446000,
#   'headline': 'Your Digital Self: AI will make video games look like nothing you’ve ever played before',
#   'id': 7317290,
#   'image': 'https://images.mktw.net/im-463754/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Potentially half of all video game content will be developed from generative AI within a decade.',
#   'url': 'https://www.marketwatch.com/story/ai-will-make-video-games-look-like-nothing-youve-ever-played-before-5e36858e'},
#  {'category': 'top news',
#   'datetime': 1699445880,
#   'headline': 'Michael Brush: Grab these 2 funds with rich 11%-12% yields while you can',
#   'id': 7317291,
#   'image': 'https://images.mktw.net/im-879591/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'If you invest for income, consider taking advantage of these unusual opportunities.',
#   'url': 'https://www.marketwatch.com/story/grab-these-2-funds-with-rich-11-12-yields-while-you-can-f2856fb2'},
#  {'category': 'top news',
#   'datetime': 1699445820,
#   'headline': 'Economic Report: Mortgage rates register sharpest drop in over a year amid signs of a weakening U.S. economy',
#   'id': 7317292,
#   'image': 'https://images.mktw.net/im-883162/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Mortgage applications rose 2.5% in the latest week, the Mortgage Bankers Association said. The average rate for a 30-year mortgage is 7.61%.',
#   'url': 'https://www.marketwatch.com/story/mortgage-rates-register-sharpest-drop-in-over-a-year-amid-signs-of-a-weakening-u-s-economy-b024008c'},
#  {'category': 'top news',
#   'datetime': 1699445640,
#   'headline': 'Need to Know: Just turned 50? Here’s where Howard Marks suggests investing for the next 10 years.',
#   'id': 7317293,
#   'image': 'https://images.mktw.net/im-572749/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "From Hong Kong, Oaktree's Howard Marks and some other top investors discuss where a 50-year old might want to put money for the next decade.",
#   'url': 'https://www.marketwatch.com/story/just-turned-50-heres-where-howard-marks-suggests-investing-for-the-next-10-years-d3e489ef'},
#  {'category': 'top news',
#   'datetime': 1699445400,
#   'headline': ': Biogen quarterly results top estimates despite complex launch of new Alzheimer’s treatment',
#   'id': 7317294,
#   'image': 'https://images.mktw.net/im-448250/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Company focuses on new products in Alzheimer's, postpartum depression as multiple sclerosis product revenues decline",
#   'url': 'https://www.marketwatch.com/story/biogen-quarterly-results-top-estimates-despite-complex-launch-of-new-alzheimers-treatment-3b16535c'},
#  {'category': 'top news',
#   'datetime': 1699444800,
#   'headline': 'Washington Watch: Not one S&P 500 CEO is donating to Donald Trump',
#   'id': 7317295,
#   'image': 'https://images.mktw.net/im-881883/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': '',
#   'url': 'https://www.marketwatch.com/story/not-one-s-p-500-ceo-is-donating-to-donald-trump-2642604b'},
#  {'category': 'top news',
#   'datetime': 1699442880,
#   'headline': 'The View From Unretirement: These Gen X and boomer Americans are doing amazing things in the second half of life',
#   'id': 7317296,
#   'image': 'https://images.mktw.net/im-879591/horizontal',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Passion careers, going back to school and scaling mountains prove there’s so much more to life after age 50.',
#   'url': 'https://www.marketwatch.com/story/these-gen-x-and-boomer-americans-are-doing-amazing-things-in-the-second-half-of-life-7f7ddd13'},
#  {'category': 'top news',
#   'datetime': 1699442520,
#   'headline': ': Country Garden shares rally on disputed report that Ping An was asked to buy it',
#   'id': 7317297,
#   'image': 'https://images.mktw.net/im-883284/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Country Garden ended sharply higher on Wednesday after a report that the Chinese government wanted Ping An Insurance to take control of the company.',
#   'url': 'https://www.marketwatch.com/story/country-garden-shares-rally-on-disputed-report-that-ping-an-was-asked-to-buy-it-19955467'},
#  {'category': 'top news',
#   'datetime': 1699441620,
#   'headline': 'TaxWatch: 5% yields on savings accounts and CDs are great — until tax time. Here’s how to prep.',
#   'id': 7317259,
#   'image': 'https://images.mktw.net/im-882182/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "'You’re going to have to pay a lot of that back in taxes,' says one tax expert on the tax bills awaiting cash savers.",
#   'url': 'https://www.marketwatch.com/story/5-yields-on-savings-accounts-and-cds-are-great-until-tax-time-heres-how-to-prep-a7de80a4'},
#  {'category': 'top news',
#   'datetime': 1699441320,
#   'headline': ': Adidas sells another $373 million worth of Yeezy stock after cutting ties with Kanye West',
#   'id': 7317260,
#   'image': 'https://images.mktw.net/im-883278/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': '',
#   'url': 'https://www.marketwatch.com/story/adidas-sells-another-373-million-worth-of-yeezy-stock-after-cutting-ties-with-kanye-west-fdebf198'},
#  {'category': 'top news',
#   'datetime': 1699441080,
#   'headline': 'Bond Report: Ten-year Treasury yields inch higher ahead of $40 billion auction',
#   'id': 7317261,
#   'image': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Bond yields rose on Wednesday ahead of a 10-year Treasury auction and a slew of Federal Reserve speakers',
#   'url': 'https://www.marketwatch.com/story/ten-year-treasury-yields-inch-higher-ahead-of-40-billion-auction-60e5598c'},
#  {'category': 'top news',
#   'datetime': 1699439640,
#   'headline': 'Movers & Shakers: Take-Two Interactive shares surge on report of new Grand Theft Auto game as Robinhood stock drops on earnings miss',
#   'id': 7317262,
#   'image': 'https://images.mktw.net/im-883266/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Shares in Take-Two Interactive, Enovix, Rivian, Sleep Number, Vroom, Robinhood Markets, Ebay and Klayviyo were active in pre market trading',
#   'url': 'https://www.marketwatch.com/story/take-two-interactive-shares-surge-on-report-of-new-grand-theft-auto-game-as-robinhood-stock-drops-on-earnings-miss-3743bcbd'},
#  {'category': 'top news',
#   'datetime': 1699437720,
#   'headline': 'Kelley Blue Book: The 2024 Toyota GR Supra review: An enthusiast’s machine with plenty of muscle, speed and agility',
#   'id': 7317230,
#   'image': 'https://images.mktw.net/im-880532/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'The 2024 Toyota GR Supra coupe, a collaboration with BMW, is made for the joy of driving, with great engines and a superb chassis. Pricing starts at $45,540.',
#   'url': 'https://www.marketwatch.com/story/the-2024-toyota-gr-supra-review-an-enthusiasts-machine-with-plenty-of-muscle-speed-and-agility-0b6f6bfd'},
#  {'category': 'top news',
#   'datetime': 1699437720,
#   'headline': 'The Moneyist: ‘I cook and clean’: I live with my boyfriend. We’re both 51. I pay for all utilities and groceries. Now he wants me to pay half his mortgage.',
#   'id': 7317231,
#   'image': 'https://images.mktw.net/im-883128/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "'I am very confused on how to handle this. Some people say pay half and others say move out'",
#   'url': 'https://www.marketwatch.com/story/i-cook-and-clean-i-live-with-my-boyfriend-were-both-51-i-pay-for-all-utilities-and-groceries-now-he-wants-me-to-pay-half-his-mortgage-a63ecb1b'},
#  {'category': 'top news',
#   'datetime': 1699437660,
#   'headline': 'NerdWallet: An IUL for retirement? The pros and cons of indexed universal life insurance compared to a 401(k).',
#   'id': 7317232,
#   'image': 'https://images.mktw.net/im-881171/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'When it comes to IUL versus a 401(k) plan, which one wins out? Before cashing out your 401(k) for one of these life insurance policies, read the fine print.',
#   'url': 'https://www.marketwatch.com/story/an-iul-for-retirement-the-pros-and-cons-of-indexed-universal-life-insurance-compared-to-a-401-k-3ad8d613'},
#  {'category': 'top news',
#   'datetime': 1699437600,
#   'headline': 'Next Avenue: Retirement communities are going solar, and it’s attracting residents',
#   'id': 7317233,
#   'image': 'https://images.mktw.net/im-880297/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Forward-thinking developers are making the most of the Sunbelt's sun to cool homes and reduce the impact on the planet.",
#   'url': 'https://www.marketwatch.com/story/retirement-communities-are-going-solar-and-its-attracting-residents-b4f913d8'},
#  {'category': 'top news',
#   'datetime': 1699437180,
#   'headline': 'Market Snapshot: S&P 500 futures edge lower after seven-day winning streak, best in two years',
#   'id': 7317234,
#   'image': 'https://images.mktw.net/im-872419/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Equity index futures were a fraction softer as traders cooled their heels following a strong rally.',
#   'url': 'https://www.marketwatch.com/story/s-p-500-futures-edge-lower-after-seven-day-winning-streak-best-in-two-years-9e4645ca'},
#  {'category': 'top news',
#   'datetime': 1699435320,
#   'headline': 'Europe Markets: Warning on U.S. commercial real estate drags German bank shares lower',
#   'id': 7317235,
#   'image': 'https://images.mktw.net/im-883254/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Shares of a German lender fell as much as 14% after a profit warning due to the struggling commercial real estate market in the U.S.',
#   'url': 'https://www.marketwatch.com/story/warning-on-u-s-commercial-real-estate-drags-german-bank-shares-lower-2018c9f5'},
#  {'category': 'top news',
#   'datetime': 1699415580,
#   'headline': 'MarketWatch First Take: Rivian and Lucid earnings show EV makers going in different directions',
#   'id': 7317168,
#   'image': 'https://images.mktw.net/im-864839/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Contrasting results and forecasts from electric-vehicle makers on Tuesday showed that Rivian Automotive Inc. has a more tangible business model than Lucid Group Inc.',
#   'url': 'https://www.marketwatch.com/story/rivian-and-lucid-earnings-show-ev-makers-going-in-different-directions-a0cb2170'},
#  {'category': 'top news',
#   'datetime': 1699413360,
#   'headline': 'Dow Jones Newswires: BOJ may tweak monetary easing before real wages turn positive',
#   'id': 7317162,
#   'image': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Bank of Japan Gov. Kazuo Ueda said Wednesday that the bank could consider unwinding its monetary easing before the pace of wage growth exceeds that of inflation.',
#   'url': 'https://www.marketwatch.com/story/boj-may-tweak-monetary-easing-before-real-wages-turn-positive-04038235'},
#  {'category': 'top news',
#   'datetime': 1699408680,
#   'headline': ': Benioff says Salesforce’s Dreamforce conference will stay in San Francisco in 2024',
#   'id': 7317156,
#   'image': 'https://images.mktw.net/im-883157/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': "Salesforce Inc.'s massive Dreamforce conference will remain in San Francisco next year, after Chief Executive Marc Benioff threatened to move it to another city.",
#   'url': 'https://www.marketwatch.com/story/benioff-says-salesforces-dreamforce-conference-will-stay-in-san-francisco-in-2024-98cfdbb7'},
#  {'category': 'top news',
#   'datetime': 1699406974,
#   'headline': 'Democrat Gabe Amo projected to win open House seat in Rhode Island',
#   'id': 7317149,
#   'image': 'https://image.cnbcfm.com/api/v1/image/107328122-1698954158764-AP23249085605805.jpg?v=1698954276&w=1920&h=1080',
#   'related': '',
#   'source': 'CNBC',
#   'summary': 'Amo defeated Republican Gerry Leonard, a Naval War college graduate who served in the Marines for three decades.',
#   'url': 'https://www.cnbc.com/2023/11/07/democrat-gabe-amo-projected-winner-of-open-house-seat-in-rhode-island-.html'},
#  {'category': 'top news',
#   'datetime': 1699404900,
#   'headline': ': Virgin Galactic to cut staff to focus on lower-cost Delta spacecraft',
#   'id': 7317150,
#   'image': 'https://images.mktw.net/im-883137/social',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'Commercial space-flight operator Virgin Galactic Holdings Inc. on Tuesday said it would cut staff in an effort to focus on developing its new class of Delta spacecraft that are expected to cost less and bring more profit.',
#   'url': 'https://www.marketwatch.com/story/virgin-galactic-to-cut-staff-to-focus-on-lower-cost-delta-ships-7af7fbc9'}]
