# %%
import json
import requests
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import pipeline
import openai
import torch
import finnhub
from newsplease import NewsPlease

# %%
# API config
finnhub_api_key = 'cl6b0r1r01ql8jir6omgcl6b0r1r01ql8jir6on0'
finnhub_client = finnhub.Client(api_key=finnhub_api_key)

# %%
result = finnhub_client.company_news('MS', _from="2023-01-01", to="2023-11-11")
result
# Out:
# [{'category': 'company',
#   'datetime': 1699731655,
#   'headline': 'Dividend Champion, Contender, And Challenger Highlights: Week Of November 12',
#   'id': 123817488,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1072593728/image_1072593728.jpg?io=getty-c-w1536',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': 'A weekly summary of dividend activity for Dividend Champions, Contenders, and Challengers. Read more to see the November 12 weekly update.',
#   'url': 'https://finnhub.io/api/news?id=1e799eea3efce69ede890d0421ff21ba894ea358c74f661c3dde68d464bae9a8'},
#  {'category': 'company',
#   'datetime': 1699636860,
#   'headline': 'Top Research Reports for NVIDIA, Chevron & AbbVie',
#   'id': 123791834,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/cMb9wkghiLrTdmTqwtu6LA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD05NDA-/https://media.zenfs.com/en/zacks.com/285a402ddc58affb5ade5ccebc4c52e0',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "Today's Research Daily features new research reports on 16 major stocks, including NVIDIA Corporation (NVDA), Chevron Corporation (CVX) and AbbVie Inc. (ABBV).",
#   'url': 'https://finnhub.io/api/news?id=5280843a4f20326dd122f8a5a3cfb38e9531ec4790b64feb18d4a0c5778975ae'},
#  {'category': 'company',
#   'datetime': 1699634340,
#   'headline': 'Morgan Stanley stock rises Friday, still underperforms market',
#   'id': 123808721,
#   'image': 'https://images.mktw.net/im-220105/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Morgan Stanley rose 1.54% to $75.33 Friday, on what proved to be an all-around great trading session for the stock market, with the S&P 500 Index...',
#   'url': 'https://finnhub.io/api/news?id=4a345af51fee526b8d39a855e003d8420220d753faa8e75cd2973149fbef2601'},
#  {'category': 'company',
#   'datetime': 1699615860,
#   'headline': 'Small-Cap Stocks Have Had a Rough Year. It’s Time to Buy.',
#   'id': 123808722,
#   'image': 'https://images.barrons.com/im-61333784/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'The S&P Small Cap 600 trades at about 12 times expected EPS for the next 12 months, a 34% discount to the S&P 500’s 18.2 times.',
#   'url': 'https://finnhub.io/api/news?id=bbca19214de88880849655d78f2b4afe5f8c668c136abe1b84d109790714f180'},
#  {'category': 'company',
#   'datetime': 1699579320,
#   'headline': 'Goldman Sachs Advances with AI for Coding and Documentation, Stresses Human Oversight in Tech Integration',
#   'id': 123800940,
#   'image': '',
#   'related': 'MS',
#   'source': 'Benzinga',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=99deb1d8a24817a169c6e841f0143ac9bb92eee24728c291c4bf7683064a30f2'},
#  {'category': 'company',
#   'datetime': 1699561126,
#   'headline': 'Morgan Stanley Stock Falls After Report on Fed Probe',
#   'id': 123767969,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/WLAo0_vIC1JeG9FjXJE4HQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MDA-/https://media.zenfs.com/en/wsj.com/cc5fdc2a90dfc7f5fa53efe2ac740412',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "Morgan Stanley's stock is down more than 2%, worse than other big banks, following a Wall Street Journal report that the Federal Reserve is scrutinizing its international wealth-management business.",
#   'url': 'https://finnhub.io/api/news?id=259d8244f8cdddf9b0bb083cc92ceb0c4649a86b163285010aaf6d15aafa214e'},
#  {'category': 'company',
#   'datetime': 1699553460,
#   'headline': "Morgan Stanley's (MS) Wealth Arm Scrutinized by Federal Reserve",
#   'id': 123760995,
#   'image': 'https://media.zenfs.com/en/zacks.com/ed0ae7e634b1ed286adce15947ed49da',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "The Federal Reserve is probing Morgan Stanley's (MS) wealth management division to check how it handles foreign clients.",
#   'url': 'https://finnhub.io/api/news?id=c33c1b88482b5de947149fa04d71dda5567ef44fd5497a69ff3bcba79a0d8a75'},
#  {'category': 'company',
#   'datetime': 1699551115,
#   'headline': 'Morgan Stanley faces Fed probe over foreign client vetting: WSJ',
#   'id': 123767973,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/B2c9keyRgrycCGruG_3nWg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzQ-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/58dba050-7f25-11ee-bd7e-18824b0ac7a9',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "The Federal Reserve is investigating how Morgan Stanley's wealth division (MS) has been vetting foreign clients, according to a report from The Wall Street Journal. According to the report, the Fed wants to ensure the proper controls in place to make sure there isn't money laundering occurring. Yahoo Finance has reached out to Morgan Stanley for comment. Yahoo Finance Live breaks down the report.\xa0 For more expert insight and the latest market action, click here to watch this full episode of Yahoo Finance Live.",
#   'url': 'https://finnhub.io/api/news?id=d03f4387bfba145d1d7889bc57faae01b54d375e45a0aa24f9392b8d575f1743'},
#  {'category': 'company',
#   'datetime': 1699549140,
#   'headline': 'Fed Probes Morgan Stanley’s Work With Foreign Clients: Report',
#   'id': 123757590,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/r4HARaGkhV6N6QCLKOzjcw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MDA-/https://media.zenfs.com/en/Barrons.com/09de2d919283076cb550e127738f0fce',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'As wealth management and foreign clients have become a bigger part of Morgan Stanley’s business, the company’s anti-money-laundering policies have come under investigation.',
#   'url': 'https://finnhub.io/api/news?id=0c97342bbac80c4e29f3c2e5883e6b24b370fe86875645ec8daa3ff81a33dce4'},
#  {'category': 'company',
#   'datetime': 1699547940,
#   'headline': 'Morgan Stanley stock underperforms Thursday when compared to competitors',
#   'id': 123808723,
#   'image': 'https://images.mktw.net/im-220105/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Morgan Stanley shed 2.34% to $74.19 Thursday, on what proved to be an all-around rough trading session for the stock market, with the S&P 500 Index...',
#   'url': 'https://finnhub.io/api/news?id=861adac15d10b2939d842528cfaecca514af1409ea0901ce7652ac05e9863177'},
#  {'category': 'company',
#   'datetime': 1699547400,
#   'headline': 'Morgan Stanley Schedules Quarterly Investor Conference Call',
#   'id': 123774578,
#   'image': '',
#   'related': 'MS',
#   'source': 'Business Wire',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=f956db9dbf7745c5ce28e83657b503da03222f32937b7dcc46d64b9f0ca0676f'},
#  {'category': 'company',
#   'datetime': 1699531980,
#   'headline': 'JP Morgan Advances AI Banking Projects Under Regulatory Guidance',
#   'id': 123761980,
#   'image': '',
#   'related': 'MS',
#   'source': 'Benzinga',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=452baa24d1a9aa9f52ee000268de941ac22089c1c4e52890d40f42bb9d354c98'},
#  {'category': 'company',
#   'datetime': 1699530054,
#   'headline': "UPDATE 1-India's Tata Technologies in talks with Morgan Stanley, US funds for IPO investment -sources",
#   'id': 123753114,
#   'image': '',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "India's Tata Technologies is in talks with Morgan Stanley Investment Management, Blackrock and some U.S hedge funds to invest in its initial public offering at a valuation of $2.5 billion, two sources with direct knowledge of the matter said.  Part of conglomerate Tata Group, the company provides engineering services for companies in the auto and aerospace sectors among others.",
#   'url': 'https://finnhub.io/api/news?id=2c3e193fe9a01a652d21502f8bc5be9fc980bf768fbab99a3f9b8a89f0463c20'},
#  {'category': 'company',
#   'datetime': 1699529700,
#   'headline': 'December 29th Options Now Available For Morgan Stanley (MS)',
#   'id': 123774582,
#   'image': '',
#   'related': 'MS',
#   'source': 'Stock Options Channel',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=e2873f1b86c5363a5eb56f85e5b835ceb83748c4488f890fb184f71d89b8d711'},
#  {'category': 'company',
#   'datetime': 1699527660,
#   'headline': 'Four stocks to consider investing in before the year-end',
#   'id': 123758398,
#   'image': '',
#   'related': 'MS',
#   'source': 'Seeking Alpha',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=fbf91e9c8c0ebadc6c449abf04500785b3d9e047f7b662f78cd02a7732ce6b7b'},
#  {'category': 'company',
#   'datetime': 1699527360,
#   'headline': 'What You Missed On Wall Street This Morning',
#   'id': 123758994,
#   'image': '',
#   'related': 'MS',
#   'source': 'Thefly.com',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=5ca2a1aca32e3209cdf3a27069eec0c6fbc99e246039db879e2c8673910c12b6'},
#  {'category': 'company',
#   'datetime': 1699526305,
#   'headline': 'Morgan Stanley wealth management business faces Fed probe: report',
#   'id': 123767975,
#   'image': 'https://www.bankingdive.com/imgproxy/ptz_pWta07oBD-E0TzLMut2i3FQ88SJLvUGUot-67jg/g:ce/rs:fill:770:435:0/bG9jYWw6Ly8vZGl2ZWltYWdlL0dldHR5SW1hZ2VzLTgyODc1MzM5LmpwZw.jpg',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'The investment bank’s vetting processes for potential foreign clients has been under investigation by the central bank since 2020, according to The Wall Street Journal.',
#   'url': 'https://finnhub.io/api/news?id=a6c2ca7ce1f9286e2950ae135d3a37cf63e6652cf1cf450bab3f71da19a57b4a'},
#  {'category': 'company',
#   'datetime': 1699523069,
#   'headline': "India's Tata Technologies in talks with Morgan Stanley, US funds for IPO investments-sources",
#   'id': 123753115,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "India's Tata Technologies is in talks with Morgan Stanley Investment Management, Blackrock and some U.S hedge funds to invest in its initial public offering at a valuation of $2.5 billion, two sources with direct knowledge said.  Part of conglomerate Tata Group, the company provides engineering services for companies in the auto and aerospace sectors among others.",
#   'url': 'https://finnhub.io/api/news?id=580188c625b9bb1d74942127a8df0d44dff91df717828fc47c70114d574bd9a3'},
#  {'category': 'company',
#   'datetime': 1699506900,
#   'headline': 'Morgan Stanley probed over international practices, safeguards, WSJ says',
#   'id': 123774587,
#   'image': '',
#   'related': 'MS',
#   'source': 'Thefly.com',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=ac8090a5f1aa155ad2072f98a590f7e2f3d776cedb2f9c5fff7376aae4a5e2cd'},
#  {'category': 'company',
#   'datetime': 1699500840,
#   'headline': 'Morgan Stanley wealth management arm under Fed probe over due diligence lapses',
#   'id': 123774589,
#   'image': '',
#   'related': 'MS',
#   'source': 'Seeking Alpha',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=fdaae52d33494ecb4df327f24169f957b1963108014b5123ac971fa8477097b6'},
#  {'category': 'company',
#   'datetime': 1699500660,
#   'headline': 'What You Missed On Wall Street On Thursday',
#   'id': 123763175,
#   'image': '',
#   'related': 'MS',
#   'source': 'Thefly.com',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=63959f5f142d75e713e5c64cf126315520da924fb0918c67eaf40eeaf247c1f5'},
#  {'category': 'company',
#   'datetime': 1699499880,
#   'headline': '3 Stocks That Are About to Get Absolutely Crushed in Q4',
#   'id': 123762935,
#   'image': '',
#   'related': 'MS',
#   'source': 'InvestorPlace',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=c6185db8c72d9b4fb51108f5a0ed85eb789bb619be804aca9adda5fb0861c5ee'},
#  {'category': 'company',
#   'datetime': 1699496100,
#   'headline': 'Fed probes Morgan Stanley’s international wealth management practices',
#   'id': 123777587,
#   'image': 'https://images.fnlondon.com/im-884145/?width=749&height=499',
#   'related': 'MS',
#   'source': 'DowJones',
#   'summary': 'At issue is how the bank vets foreigners and the origins of their money before taking them on as customers',
#   'url': 'https://finnhub.io/api/news?id=39f857a7cb30ce8d7cc1ace5f0d289a2871b60991821848fde75a0bc103c3471'},
#  {'category': 'company',
#   'datetime': 1699495380,
#   'headline': 'David Einhorn Issues Stock Market Warning: ‘We’re on a Buyer’s Strike’',
#   'id': 123766499,
#   'image': '',
#   'related': 'MS',
#   'source': 'InvestorPlace',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=920ebdcc36e2a4804a504006d178d2f9dd0574e0492f11a7fe2df2176da6178c'},
#  {'category': 'company',
#   'datetime': 1699484255,
#   'headline': "US Fed probes Morgan Stanley's international wealth-management practices - WSJ",
#   'id': 123737235,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "Morgan Stanley's wealth management is being scrutinized by the U.S. Federal Reserve, the Wall Street Journal reported on Wednesday citing people familiar with the matter.  The regulator is looking into whether the bank has sufficient controls in place to prevent rich foreign customers from laundering money, the Journal's report added.  The Fed has privately reprimanded the bank for not making all the required changes, and Morgan Stanley's wealth management business head, Andy Saperstein, has been meeting with Fed officials to address the issues, according to the report.",
#   'url': 'https://finnhub.io/api/news?id=e6dcf157cef9f07567dea635c526c456af30f86bb5cd360ad8d7e7f7d0a2929f'},
#  {'category': 'company',
#   'datetime': 1699481940,
#   'headline': 'Fed Probes Morgan Stanley’s International Wealth-Management Practices',
#   'id': 123737237,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/N2ZIT9z4vBwbBDfSaWgA0g--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MDA-/https://media.zenfs.com/en/wsj.com/17fc9728964cd73f0e077874d4c297f4',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'At issue is how the bank vets foreigners and the origins of their money before taking them on as customers.',
#   'url': 'https://finnhub.io/api/news?id=a2ac995c8844caee52e139a52ea819a003d34f9ff32cf81c525e4b30125e085c'},
#  {'category': 'company',
#   'datetime': 1699461540,
#   'headline': 'Morgan Stanley stock outperforms competitors on strong trading day',
#   'id': 123808725,
#   'image': 'https://images.mktw.net/im-220105/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Morgan Stanley inched 0.61% higher to $75.97 Wednesday, on what proved to be an all-around mixed trading session for the stock market, with the S&P...',
#   'url': 'https://finnhub.io/api/news?id=d83a04ea93546c7941d80d69e4b176d94a33ea7901851c0669cec930b25c5553'},
#  {'category': 'company',
#   'datetime': 1699443360,
#   'headline': 'Why Is Morgan Stanley (NYSE:MS) Under Probe?',
#   'id': 123774593,
#   'image': '',
#   'related': 'MS',
#   'source': 'TipRanks',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=1bab1a8a0c31df110e72abface444e50409d8342ff2039c7e9e0713f8a1bc87b'},
#  {'category': 'company',
#   'datetime': 1699442460,
#   'headline': 'Morgan Stanley Unusual Options Activity For November 08',
#   'id': 123742359,
#   'image': '',
#   'related': 'MS',
#   'source': 'Benzinga',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=55af424cb5e6255841317598858a443d152043bb813a0068a40997e44452f5f3'},
#  {'category': 'company',
#   'datetime': 1699440120,
#   'headline': '3 Top Cryptos to Buy for the Next Bull Run',
#   'id': 123742360,
#   'image': '',
#   'related': 'MS',
#   'source': 'InvestorPlace',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=d9cfc31eec191caff5058a7965ee09e02f3d91c68e5e2f7be0acaae6ec80731c'},
#  {'category': 'company',
#   'datetime': 1699411500,
#   'headline': 'LONDON BRIEFING: M&S profit surges; JD Wetherspoon upping investment',
#   'id': 123724691,
#   'image': '',
#   'related': 'MS',
#   'source': 'Alliance News',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=bbd93a54928bc8bbdf9713d7f057ba1cfd09f2e4ea36132b8751cda7bd204b35'},
#  {'category': 'company',
#   'datetime': 1699375140,
#   'headline': 'Morgan Stanley stock falls Tuesday, underperforms market',
#   'id': 123711705,
#   'image': 'https://images.mktw.net/im-220105/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Morgan Stanley slumped 0.54% to $75.51 Tuesday, on what proved to be an all-around great trading session for the stock market, with the S&P 500...',
#   'url': 'https://finnhub.io/api/news?id=e16ca666088c50d8c2151d308f473f1dcb2884fc04a5afcbf522240cd491af61'},
#  {'category': 'company',
#   'datetime': 1699363703,
#   'headline': 'High Yield Stock Watchlist - November 2023',
#   'id': 123691730,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1456222076/image_1456222076.jpg?io=getty-c-w1536',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': 'The majority of the 22 stocks on my high yield watchlist for November 2023 are undervalued based on dividend yield theory. Click here for the complete list.',
#   'url': 'https://finnhub.io/api/news?id=65bc419010f6db36ff6183b34ca9eaa39004ff43f18139b757dabd3c6b58c08d'},
#  {'category': 'company',
#   'datetime': 1699353000,
#   'headline': 'Big Banks Cook Up New Way to Unload Risk',
#   'id': 123685059,
#   'image': '',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Banks are selling risk to hedge funds and private-equity firms through so-called synthetic risk transfers.',
#   'url': 'https://finnhub.io/api/news?id=9291db9087d3a683791198f73ac9019806828f9ffec06d5d8ee04ffe0938425e'},
#  {'category': 'company',
#   'datetime': 1699349942,
#   'headline': '20 Most Valuable Financial Companies in the World',
#   'id': 123681183,
#   'image': 'https://media.zenfs.com/en/insidermonkey.com/93e6f3ae4625a69b17b326094319b46c',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'In this article, we will look into the 20 most valuable financial companies in the world. If you want to skip our detailed analysis, you can go directly to the 5 Most Valuable Financial Companies in the World. Financial Services Industry: A Market Analysis According to a report by The Business Research Company, the global […]',
#   'url': 'https://finnhub.io/api/news?id=a95196807c7836e6682381421fe79d337daac6f13dfe0d1063d787a8889bb35a'},
#  {'category': 'company',
#   'datetime': 1699349640,
#   'headline': "Here's How Much You Would Have Made Owning Morgan Stanley Stock In The Last 15 Years",
#   'id': 123704984,
#   'image': '',
#   'related': 'MS',
#   'source': 'Benzinga',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=cc2577cd8ef61c20dff3be2731cec887ec58432dfecaea3e1f15d2590a7a1b59'},
#  {'category': 'company',
#   'datetime': 1699342440,
#   'headline': 'Geopolitical clash could still spark market incident, Deutsche Bank CEO warns',
#   'id': 123704985,
#   'image': '',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=705823279f404af7e43aafe55f0cdbdc8b2350119843063d3ea331125cbfc2a9'},
#  {'category': 'company',
#   'datetime': 1699338960,
#   'headline': 'AIB Group poised for future as Irish Department of Finance trims stake',
#   'id': 123700710,
#   'image': '',
#   'related': 'MS',
#   'source': 'Alliance News',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=0ce1210b54355bd939d91fba2a5cd55e76219500e7c3f357f7324744cf8bb2b8'},
#  {'category': 'company',
#   'datetime': 1699328082,
#   'headline': 'Morgan Stanley CEO Sees Next Chapter for ‘Best’ Banking JV',
#   'id': 123678548,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/CEx7tr5w1czzNmgWywpQsw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/bloomberg_markets_842/8e131bcb292fa763d0601184ce41eb26',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- Morgan Stanley’s alliance with Mitsubishi UFJ Financial Group Inc. will last for at least another decade, the US bank’s outgoing chief executive officer said, hailing recent steps by their two joint ventures in Japan to deepen ties.Most Read from BloombergTrump Testimony Called a ‘Broken Record’ by Judge: Trial UpdateIsrael Latest: Netanyahu Sees a Role in Gaza Security After WarWeWork Goes Bankrupt, Signs Pact With Creditors to Cut DebtWall Street Faces ‘Reality Check’ After Big',
#   'url': 'https://finnhub.io/api/news?id=99948fe43934cd9cb32f1f3cd9f63feaa5b61d9d30d61954a8c846b06951fb40'},
#  {'category': 'company',
#   'datetime': 1699324980,
#   'headline': 'LONDON BRIEFING: AB Foods hails Primark; Beazley premiums rise',
#   'id': 123688042,
#   'image': '',
#   'related': 'MS',
#   'source': 'Alliance News',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=97219b0a63824967a8e51990e29556b34c667cac8b3e3adbe209c6104de9da90'},
#  {'category': 'company',
#   'datetime': 1699288740,
#   'headline': 'Morgan Stanley stock falls Monday, underperforms market',
#   'id': 123711706,
#   'image': 'https://images.mktw.net/im-220105/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Morgan Stanley sank 0.45% to $75.92 Monday, on what proved to be an all-around great trading session for the stock market, with the S&P 500 Index...',
#   'url': 'https://finnhub.io/api/news?id=d586558ffa247556b8ea3cbb9a0d84fe960236cd700bd84eedb57c21e3fa1f6e'},
#  {'category': 'company',
#   'datetime': 1699288500,
#   'headline': 'NEW YORK MARKET CLOSE: Stocks creep higher, building on stellar gains',
#   'id': 123669637,
#   'image': '',
#   'related': 'MS',
#   'source': 'Alliance News',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=f46579cded8a93552129e9c76fb9537d0b799f2c0c47468ea88e5010a2be3743'},
#  {'category': 'company',
#   'datetime': 1699274640,
#   'headline': 'JPMorgan’s and PNC’s mixed outlook on net interest income draws attention from analyst after industry gathering',
#   'id': 123701718,
#   'image': 'https://images.mktw.net/im-881972/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Banks are expecting their net interest income to bottom out in the next few quarters as the economy adjusts to higher interest rates.',
#   'url': 'https://finnhub.io/api/news?id=871599996185b107d866c1cc35c4d8b47e2675bc02b261e92bf33f5133a127bc'},
#  {'category': 'company',
#   'datetime': 1699270800,
#   'headline': 'Birkenstock Shares Can Rise 13%, Analysts Say. Wall Street Is Weighing In After IPO.',
#   'id': 123711708,
#   'image': 'https://images.barrons.com/im-24602133/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'A wave of Buy recommendations came in on Monday and over the weekend.',
#   'url': 'https://finnhub.io/api/news?id=64981867b464c12805547302e0b3ab736dbcbd02f845d3dadd299062dd258abd'},
#  {'category': 'company',
#   'datetime': 1699268820,
#   'headline': 'Bank Stocks Hit Historic 80-Year Low Vs. S&P 500: Analyst Sees Bear Market Bounce As Fed Rates Peak',
#   'id': 123661990,
#   'image': '',
#   'related': 'MS',
#   'source': 'Benzinga',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=2e497a3035fe856be1955cd4d692411fa2ebd60c2f88e74c3cfe7af7f08ea589'},
#  {'category': 'company',
#   'datetime': 1699266600,
#   'headline': 'The New Headache for Bosses: Employees Aren’t Quitting',
#   'id': 123656089,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/cy54UTuIbvdVHPjdppPkug--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MDA-/https://media.zenfs.com/en/wsj.com/328b70dfee7a0c85afb1ca4fecd6b433',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Just last year, companies were scrambling to keep staff. Now, they say not enough people are leaving their jobs.',
#   'url': 'https://finnhub.io/api/news?id=c50a5a9841a2f9f84176ee15f1d3aa5269717eb194f7f4ed484db0b0f43c82f4'},
#  {'category': 'company',
#   'datetime': 1699257751,
#   'headline': 'U.S. Bank, KeyBank may be next on the WhatsApp hit list',
#   'id': 123666382,
#   'image': 'https://www.bankingdive.com/imgproxy/OXSMYrvytq_DuxDGsf2KxfXuOoT5eQk8ITBm9EtySPM/g:ce/rs:fill:770:435:0/bG9jYWw6Ly8vZGl2ZWltYWdlL0tleUJhbmtfYnJhbmNoLmpwZWc.jpg',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "A look at SEC filings from last week signal looming record-keeping penalties and a broadening probe of COVID-era unemployment benefits at the nation's largest “super-regional.”",
#   'url': 'https://finnhub.io/api/news?id=71671dfa16a2ea102b80f048c7d5fcf39e05cfa75790eafcbcca82895a62c4f5'},
#  {'category': 'company',
#   'datetime': 1699165140,
#   'headline': 'Major U.S. banks slammed with deposit delays, CNN says',
#   'id': 123648262,
#   'image': '',
#   'related': 'MS',
#   'source': 'Thefly.com',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=33e3b60bb2ee2a96c0986eea959e318b5c3540e492df306fa7b1defa8c269e80'},
#  {'category': 'company',
#   'datetime': 1699098000,
#   'headline': 'Morgan Stanley: Grab A 6.5% Dividend Yield From Preferred Shares',
#   'id': 123630340,
#   'image': 'https://media.gettyimages.com/id/1461607700/nl/foto/morgan-stanley-investment-bank.jpg?b=1&s=170667a&w=0&k=20&c=ec9AUg0j7qsWXHOVFyctR6PK6lAG8Nx83lcEPOP5t7g=',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': "Morgan Stanley's Q3 financial results showed a decrease in wealth management revenue but higher margins. Learn what makes MS stock attractively priced.",
#   'url': 'https://finnhub.io/api/news?id=b785090c705e95a666bc1fce469e6115980785f68a31acba110d69866f97d1c8'},
#  {'category': 'company',
#   'datetime': 1699074772,
#   'headline': 'The Morgan Stanley (MS) Company: A Short SWOT Analysis',
#   'id': 123638550,
#   'image': '',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Unveiling the Strengths and Challenges: A Deep Dive into Morgan Stanley (MS) SWOT Analysis',
#   'url': 'https://finnhub.io/api/news?id=814cdaa932ee08369fa345e5f8f5cc261b975522d28e3a49957b772d93041520'},
#  {'category': 'company',
#   'datetime': 1699065600,
#   'headline': 'Morgan Stanley’s New CEO Inherits Rich Pickings',
#   'id': 123635776,
#   'image': '',
#   'related': 'MS',
#   'source': 'TalkMarkets',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=a194d606a0f9d8650da876da0e7288d6b1e1c45dab3e70edeabaa277f92f48de'},
#  {'category': 'company',
#   'datetime': 1699016406,
#   'headline': 'Morgan Stanley (MS) is Attracting Investor Attention: Here is What You Should Know',
#   'id': 123589274,
#   'image': 'https://media.zenfs.com/en/zacks.com/46ebfcbff417ac1bbde85ad33fa0d4be',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Recently, Zacks.com users have been paying close attention to Morgan Stanley (MS). This makes it worthwhile to examine what the stock has in store.',
#   'url': 'https://finnhub.io/api/news?id=17bb475cb6e5461ef16f36544b459308b08f5f8722a7cb751e9fe8db3275349d'},
#  {'category': 'company',
#   'datetime': 1699003260,
#   'headline': "Looking At Morgan Stanley's Recent Unusual Options Activity",
#   'id': 123608482,
#   'image': '',
#   'related': 'MS',
#   'source': 'Benzinga',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=a47e95fc92f0993ab76185f713bcc5a87dda02099ef9d5710403d98cb804f8bb'},
#  {'category': 'company',
#   'datetime': 1699001100,
#   'headline': 'SoFi Technologies Delivers A Triple Beat And Is Upgraded By Morgan Stanley After Q3',
#   'id': 123576312,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1271407322/image_1271407322.jpg?io=getty-c-w1536',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': 'Morgan Stanley upgrades SoFi Technologies from underweight to equalweight after impressive Q3 earnings and raised guidance. Learn how SOFI stock is gaining momentum.',
#   'url': 'https://finnhub.io/api/news?id=d471f65bcab6fd3ed742cdf881dc3d612638c01dfae86c92a25dfb65ee6ca59e'},
#  {'category': 'company',
#   'datetime': 1698939720,
#   'headline': "JPMorgan Chase's stock draws downgrade to hold from buy on 'too many near-term negatives'",
#   'id': 123705907,
#   'image': 'https://images.mktw.net/im-880466/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': "Analyst Richard Bove of Odeon Capital sees multiple headwinds that will dampen the stock's performance over the next year.",
#   'url': 'https://finnhub.io/api/news?id=440264463011ecc48618edf3c48bd9cf9590f2c59462cae4e276bf1490a4f711'},
#  {'category': 'company',
#   'datetime': 1698931800,
#   'headline': 'Morgan Stanley Wins Four 2023 Money Management Institute (MMI)/Barron’s Industry Awards',
#   'id': 123570644,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'NEW YORK, November 02, 2023--Morgan Stanley (NYSE: MS) announced today that it has won four Industry Awards from the Money Management Institute (MMI) and Barron’s, the most of any firm. The awards include a Digital Innovation award for Morgan Stanley’s Portfolio Risk Platform, a Disruption award for Morgan Stanley’s UMA Fractional Share Program, a Sustainable & ESG Investing Award for Morgan Stanley IQ ®, and a Doing Good award for Morgan Stanley’s Strategy Challenge.',
#   'url': 'https://finnhub.io/api/news?id=9fdbc99c970bfe3d3e9c01eec44baa155f72c5a390376686ae1c3fbfecdf35f4'},
#  {'category': 'company',
#   'datetime': 1698928740,
#   'headline': 'See Which Of The Latest 13F Filers Holds Morgan Stanley',
#   'id': 123608485,
#   'image': '',
#   'related': 'MS',
#   'source': 'Preferred Stock Channel',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=e2ce172c0afbd3e5338c6470cfbf0904a0235745bdb32a76330d76c25b48ae2b'},
#  {'category': 'company',
#   'datetime': 1698923388,
#   'headline': 'What JPMorgan Chase CEO Jamie Dimon just told investors is very important',
#   'id': 123570645,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/eTC02aiao875i3zj8asYsQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04NTE-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/b500eaa0-791e-11ee-a7ff-9e741b3fedca',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Investors should deeply consider the perspectives that the most powerful financier in the world just articulated to Yahoo Finance.',
#   'url': 'https://finnhub.io/api/news?id=84f5f3a7b884d01aa883f049bd870a114028e93c2dfc45fcd18db67b7ba7a519'},
#  {'category': 'company',
#   'datetime': 1698920220,
#   'headline': 'December 22nd Options Now Available For Morgan Stanley (MS)',
#   'id': 123608486,
#   'image': '',
#   'related': 'MS',
#   'source': 'Stock Options Channel',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=eefe4d29b514c27c053dcc78c7a8b7e62e71424532172ed5c6b2f20cc490b6ef'},
#  {'category': 'company',
#   'datetime': 1698915655,
#   'headline': 'Jamie Dimon on the Fed, inflation, and the consumer: Yahoo Finance Exclusive',
#   'id': 123569442,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/vLJ5WTuEVEYSUlnojbMDkA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/05ab4fc0-7903-11ee-bdbe-d0eb24306823',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'In an exclusive interview, JPMorgan Chase CEO Jamie Dimon (JPM) speaks with Yahoo Finance Executive Editor Brian Sozzi from the Chase for Business "Make Your Move Summit" in Frisco, Texas. Dimon first weighed in on the Federal Reserve\'s decision to keep its interest rate hiking cycle on pause. "I think they did the right thing to raise rates rapidly and I think they are kind of right to pause here a little bit and see what happens. But I suspect that they might not be done," Dimon said, adding that "there\'s a chance inflation is a little bit stickier than people think." When it comes to the consumer, Dimon thinks they are in "rather good shape" given low unemployment and high home equity values. Dimon cautioned, however, that lower-income consumers have spent the excess savings they built up during the pandemic. "The middle class is getting close to zero, no excess savings," Dimon said, "but they still have jobs and wages are going up." Dimon thinks there may be a "sea change" in the economy, noting factors like government spending and an aging population. Dimon said of the future: "I don\'t see anything which is...disinflationary." Dimon also had strong words for leaders in Washington. "D.C. goes out of its way to make it hard...for small to large businesses to grow and expand," Dimon said. "Some of our regulations are, they\'re barnacles. They\'ve been there for years. They should be taken away because they\'re just slowing down growth. I mean, I\'m in favor of good regulations, just not endless regulations." Dimon added that geopolitical concerns such as the Israel-Hamas war and Russia\'s invasion of Ukraine remain top of mind, advising the average investor to keep things like that in mind, saying "look at a potential range of outcomes and...how you feel about if those range of outcomes happened, so you\'ve really thought it through." Key video moments 00:00:45 Dimon on the Fed\'s path 00:03:50 Dimon’s take on housing 00:06:30 Dimon on the "sea change" in the economy and higher for longer rates 00:08:30 Dimon on the deficit 00:10:00 Dimon on lending to businesses 00:11:50 Dimon describes the state of the U.S. consumer 00:13:00 How Dimon feels about the U.S. government 00:16:30 Dimon on his biggest concerns, geopolitical events 00:19:50 Dimon on why he\'s hopeful for America 00:21:45 Dimon\'s message for small businesses',
#   'url': 'https://finnhub.io/api/news?id=9ccd6c6a4a303485eba0666558f67eb956980c9da0e5fa65922a2cd5bcf93990'},
#  {'category': 'company',
#   'datetime': 1698915035,
#   'headline': 'My Top 10 High Yield Dividend Stocks For November 2023',
#   'id': 123569632,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1465188429/image_1465188429.jpg?io=getty-c-w1536',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': 'The market slide continues in October with the SPDR S&P 500 Trust ETF dropping by 2.17%, marking three consecutive months of losses for the fund.',
#   'url': 'https://finnhub.io/api/news?id=0db38d9f1179b68f540762a3c3508509a86cb8ef5d823e18043a33078241b78e'},
#  {'category': 'company',
#   'datetime': 1698892980,
#   'headline': 'JPMorgan Chase’s stock draws downgrade to hold from buy on ‘too many near-term negatives’',
#   'id': 123608490,
#   'image': '',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=815dbb15fa0287249a2160e3a0b67e174de4c73c139722719c4094373c8bd8b9'},
#  {'category': 'company',
#   'datetime': 1698890739,
#   'headline': 'Financial Steals: 3 Bank Stocks With Outstanding Value',
#   'id': 123711279,
#   'image': 'https://media.zenfs.com/en/investorplace_417/c53bf0e7b223b8f778dcb03b643da0e3',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Bank stocks continue to be under pressure, with the shares of many lenders now at a 52-week low. The Standards and Practices (S&P) Banks Index is currently down 22% versus a year-to-date gain of 10% in the benchmark S&P 500 index. The continued pullback comes despite all the major American lenders posting strong third-quarter earnings that by-and-large beat Wall Street forecasts. The concerns weighing on bank stocks seem to have more to do with the impacts of high interest rates, a continued dea',
#   'url': 'https://finnhub.io/api/news?id=17f39e000705e802775393ef2149ec8a0c79df707bb5f81e4516d0701dc0c4a1'},
#  {'category': 'company',
#   'datetime': 1698869485,
#   'headline': 'Unusual Put Option Trade in Morgan Stanley (MS)  Worth $19,082.00K',
#   'id': 123548735,
#   'image': '',
#   'related': 'MS',
#   'source': 'Fintel',
#   'summary': '',
#   'url': 'https://finnhub.io/api/news?id=17b8a248aa406ab0ed6a73843c935ee7d9012bcabd8c6b0011e0d98723d44cb9'},
#  {'category': 'company',
#   'datetime': 1698856740,
#   'headline': 'Morgan Stanley stock rises Wednesday, still underperforms market',
#   'id': 123562956,
#   'image': 'https://images.mktw.net/im-220105/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Morgan Stanley inched 0.18% higher to $70.95 Wednesday, on what proved to be an all-around positive trading session for the stock market, with the...',
#   'url': 'https://finnhub.io/api/news?id=7fc686a92384ae8c5075d778fc5ef582089e2607b5f95830168a0807544432a8'},
#  {'category': 'company',
#   'datetime': 1698847860,
#   'headline': 'Bank stocks mixed after Fed leaves rates unchanged, as Bank of America dips while Goldman Sachs rises',
#   'id': 123561322,
#   'image': 'https://s.wsj.net/public/resources/MWimages/MW-GP644_MicroS_ZG_20180906154215.jpg',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Bank stocks continued to trade mixed after the Federal Reserve said it would leave interest rates unchanged, as expected. Bank of America Corp. dipped...',
#   'url': 'https://finnhub.io/api/news?id=08f7a68d2e4c2435c0517013a15d19aa465acfaf493375cc712c9c4acb29b299'},
#  {'category': 'company',
#   'datetime': 1698847200,
#   'headline': 'Endowment & Foundation Investors See Challenges Ahead, According to Graystone Consulting Study',
#   'id': 123565765,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'NEW YORK, November 01, 2023--Graystone Consulting, a business of Morgan Stanley (NYSE: MS), today published its first annual institutional investor survey. The study explores how endowments and foundations are responding to the market environment, managing their portfolios, and positioning their approaches to governance, operations, and staffing.',
#   'url': 'https://finnhub.io/api/news?id=dd3d3fe2eeac9eac160bb60d157603ae27e0c85a3a8056f3470ca33027accc8e'},
#  {'category': 'company',
#   'datetime': 1698818400,
#   'headline': '3 Stocks That Just Have No Hope Left: November 2023 Edition',
#   'id': 123546135,
#   'image': '',
#   'related': 'MS',
#   'source': 'InvestorPlace',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=549547208e4df0eb3ee807812313df2ba915d9242e619fb739770f1c0869fb0d'},
#  {'category': 'company',
#   'datetime': 1698817535,
#   'headline': 'BOJ Buys More Bonds to Slow Rising Yields a Day After Tweak',
#   'id': 123540820,
#   'image': 'https://s.yimg.com/ny/api/res/1.2/5geo8m7aX3OdcZWXbjqyBg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/bloomberg_markets_842/c2f56b522d0619fb98a63059f7335c96',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': '(Bloomberg) -- The Bank of Japan stepped into the bond market unexpectedly Wednesday to curb the pace of gains in sovereign yields, just a day after announcing it was loosening its grip on debt prices.Most Read from BloombergImmigrants Are Leaving Canada at Faster Pace, Study ShowsIsrael Latest: Blinken Returning to Israel; Refugee Camp HitZillow Plunges After Verdict on Real Estate Brokerage CommissionsSaudi Forces on Alert After Clash With Iran-Backed HouthisSony’s Bungie Game Unit Cut 8% of S',
#   'url': 'https://finnhub.io/api/news?id=6a57aaacfcc99386427b6669ec9dbebbcd2ee68f35a107f836ecfc276760eb75'},
#  {'category': 'company',
#   'datetime': 1698814818,
#   'headline': 'The dangers of succeeding a star CEO',
#   'id': 123541574,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'When Ted Pick takes over Morgan Stanley in January, he will face a problem that a lot of new chief executives would like to have: when the company has been doing this well, what can you do for a next act?  Outgoing CEO James Gorman has racked up an enviable 14-year record.  Morgan Stanley now draws more than half of its pre-tax profits from asset and wealth management and trades on a higher multiple of book value than Wall Street rival Goldman Sachs, suggesting investors rate it more highly.',
#   'url': 'https://finnhub.io/api/news?id=1402e892c445625c4beb577cad6d18385ecf25385fed31a5482ea6b93d42450e'},
#  {'category': 'company',
#   'datetime': 1698809880,
#   'headline': 'Buy and Hold These 3 High-Yielding Dividend Stocks for Long-Term Gains',
#   'id': 123553491,
#   'image': '',
#   'related': 'MS',
#   'source': 'InvestorPlace',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=be510f7bf549ad60d8d498d4ecd9e7c8679537f9570ee22c097e5fa9463f95c6'},
#  {'category': 'company',
#   'datetime': 1698779460,
#   'headline': 'Morgan Stanley Infrastructure Partners Completes Investment in Valoriza Servicios Medioambientales S.A.',
#   'id': 123527452,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'NEW YORK, October 31, 2023--Morgan Stanley Investment Management ("MSIM"), through investment funds managed by Morgan Stanley Infrastructure Partners ("MSIP"), a private infrastructure investment platform within MSIM, announced today it has closed the acquisition of Valoriza Servicios Medioambientales S.A. ("Valoriza" or the "Company") from Sacyr, S.A. ("Sacyr").',
#   'url': 'https://finnhub.io/api/news?id=9e25356b8f1d798cb4c9cb4686b5388912e762c9e1fc7f6b410a7d3c0f7bb898'},
#  {'category': 'company',
#   'datetime': 1698770340,
#   'headline': 'Morgan Stanley stock rises Tuesday, still underperforms market',
#   'id': 123562960,
#   'image': 'https://images.mktw.net/im-220105/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Morgan Stanley inched 0.33% higher to $70.82 Tuesday, on what proved to be an all-around great trading session for the stock market, with the S&P...',
#   'url': 'https://finnhub.io/api/news?id=4736c8c4c9291a45ffd959afe78ceed080d2ba07fccb8d0592094a46052d6560'},
#  {'category': 'company',
#   'datetime': 1698768398,
#   'headline': 'UPDATE 3-Morgan Stanley may pay up to $1 bln to resolve US probe into private stock sales - Semafor',
#   'id': 123527453,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Morgan Stanley may pay between $500 million and $1 billion to resolve a long-running U.S. probe into how it handled private stock sales, Semafor reported on Tuesday, citing people familiar with the matter.  The bank may also agree to tighten internal controls, as part of a potential settlement with the Department of Justice and the U.S. Securities and Exchange Commission (SEC), according to the report.  It, however, will likely not plead guilty to a crime, Semafor reported, adding that no individuals were expected to be criminally charged.',
#   'url': 'https://finnhub.io/api/news?id=5c0cb6b9c824d3b1eb0657a7297fc6b6babb3ad924e99006aea921a313240b15'},
#  {'category': 'company',
#   'datetime': 1698768276,
#   'headline': 'Morgan Stanley may pay up to $1 billion to resolve US probe into private stock sales - Semafor',
#   'id': 123527454,
#   'image': 'https://media.zenfs.com/en/reuters-finance.com/3b59bcb16325faac869cfb4fcc0ae99b',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "The bank may also agree to tighten internal controls, as part of a potential settlement with the Department of Justice and the U.S. Securities and Exchange Commission (SEC), according to the report.  It, however, will likely not plead guilty to a crime, Semafor reported, adding that no individuals were expected to be criminally charged.  Spokespeople for Morgan Stanley and the Manhattan U.S. Attorney's office declined to comment.",
#   'url': 'https://finnhub.io/api/news?id=942f4480be890edef9c37d98cd231346f23f5e7b1565f11c400b8287119b211c'},
#  {'category': 'company',
#   'datetime': 1698767400,
#   'headline': 'Companies Are Racing to Tap the Bond Market. Why They Suddenly Want to Issue Debt.',
#   'id': 123529992,
#   'image': 'https://images.barrons.com/im-02549775/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': "Monday's U.S. issuance of investment-grade corporate bonds was the highest since mid May, not counting the day after Labor Day.",
#   'url': 'https://finnhub.io/api/news?id=5fbc00a5b0e929aee894d3aeadb64583fa34c67b75b3d15d323e699d05ed31c4'},
#  {'category': 'company',
#   'datetime': 1698756480,
#   'headline': 'Morgan Stanley could pay as much as $1B to settle block-trading probe - report',
#   'id': 123525725,
#   'image': '',
#   'related': 'MS',
#   'source': 'Seeking Alpha',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
# ...
#   'url': 'https://finnhub.io/api/news?id=98f3a6c77fe10490d932d1801b5a3c18753994cc68877adfda2bad33ef5e9c38'},
#  {'category': 'company',
#   'datetime': 1698069016,
#   'headline': "Pinterest upgraded, Salesforce downgraded: Wall Street's top analyst calls",
#   'id': 123335624,
#   'image': 'https://media.zenfs.com/en/the_fly_169/135b0749a3ad5e86fe326a9da1d664b6',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "Pinterest upgraded, Salesforce downgraded: Wall Street's top analyst calls",
#   'url': 'https://finnhub.io/api/news?id=f78eb09054d234631cdf5cbf89103d9d963c05921b3f6b260f7470df9d35e14b'},
#  {'category': 'company',
#   'datetime': 1698068428,
#   'headline': 'Odeon Capital Downgrades Morgan Stanley (MS)',
#   'id': 123335602,
#   'image': '',
#   'related': 'MS',
#   'source': 'Fintel',
#   'summary': '',
#   'url': 'https://finnhub.io/api/news?id=4287af3c9eb701a9325f70dc5f4caa988151b134b323ae8cb509d45b0fabfc34'},
#  {'category': 'company',
#   'datetime': 1698067200,
#   'headline': 'Wall Street Lunch: Chevron Buys Hess',
#   'id': 123339078,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1437343231/image_1437343231.jpg?io=getty-c-w1536',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': 'Chevron to buy Hess in an all-stock transaction for $53 billion. The 10-year Treasury yield briefly crosses 5% for the first time since 2007. Read more.',
#   'url': 'https://finnhub.io/api/news?id=0882b5a98cea92ae41ce8f38bc644c099a74cb144d9d8fa010ce7b5bfaec022f'},
#  {'category': 'company',
#   'datetime': 1698066006,
#   'headline': 'Morgan Stanley (MS) Is a Trending Stock: Facts to Know Before Betting on It',
#   'id': 123336669,
#   'image': 'https://media.zenfs.com/en/zacks.com/023168c7ea091c342492be3899b280af',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Recently, Zacks.com users have been paying close attention to Morgan Stanley (MS). This makes it worthwhile to examine what the stock has in store.',
#   'url': 'https://finnhub.io/api/news?id=32f4d8641f5b8a1798367c847e7fc5e5488daadb582c4a555fc51a034f916209'},
#  {'category': 'company',
#   'datetime': 1698062520,
#   'headline': "The 10-year Treasury yield briefly pierced 5%. Here's what could drive it higher.",
#   'id': 123428117,
#   'image': 'https://images.mktw.net/im-386201/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Lisa Shalett, chief investment officer for Morgan Stanley Wealth Management, said it may be time to consider whether a higher risk premium may be required.',
#   'url': 'https://finnhub.io/api/news?id=bffa563b3a1de3773f9e86d569b7fce87643dc9aa9c71eef1839f384363d70c0'},
#  {'category': 'company',
#   'datetime': 1698059040,
#   'headline': 'The 10-year Treasury yield briefly pierced 5%. Here’s what could drive it higher.',
#   'id': 123342285,
#   'image': '',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=ab9087c1da2c0c7b863ab7030af325cfb867754a851c4b8453d4dd660cacec02'},
#  {'category': 'company',
#   'datetime': 1698049440,
#   'headline': 'Morgan Stanley downgraded to neutral from buy at Odeon Capital',
#   'id': 123428118,
#   'image': 'https://s.wsj.net/public/resources/MWimages/MW-GP644_MicroS_ZG_20180906154215.jpg',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Odeon Capital analyst Richard Bove on Monday cut his rating on Morgan Stanley to hold from buy because of a “lack of direction” in the company. Chief...',
#   'url': 'https://finnhub.io/api/news?id=f977c102af5e2928eb68ea6e54ece502332488adf24593d63e4b3d6599334593'},
#  {'category': 'company',
#   'datetime': 1698045180,
#   'headline': 'Morgan Stanley cut to Hold at Odeon due to leadership uncertainty',
#   'id': 123342291,
#   'image': '',
#   'related': 'MS',
#   'source': 'Seeking Alpha',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=6ad0386fb4de5c4a179ec2cc0e7c67332978576f4e453d04a29e061caca93c36'},
#  {'category': 'company',
#   'datetime': 1698043020,
#   'headline': "Morgan Stanley downgraded to Hold at Odeon after 'disappointing' results",
#   'id': 123342293,
#   'image': '',
#   'related': 'MS',
#   'source': 'Thefly.com',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=feb3ff68fd4a5dfb3f1299396b69575512d1d53849fc27aee14a18e60dcf16ab'},
#  {'category': 'company',
#   'datetime': 1698042780,
#   'headline': 'Morgan Stanley downgraded to Hold from Buy at Odeon Capital',
#   'id': 123342294,
#   'image': '',
#   'related': 'MS',
#   'source': 'Thefly.com',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=ed537e798630055746886e13185bff19c902d58f26b0acdc2d17c0877d5d36dd'},
#  {'category': 'company',
#   'datetime': 1698042660,
#   'headline': 'Wall Street Analysts Are Bullish on Top Financial Picks',
#   'id': 123342296,
#   'image': '',
#   'related': 'MS',
#   'source': 'TipRanks',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=5089f458f23cff4105e1f41e8f619ca2c07592464b929e3d6e469a5cb346e643'},
#  {'category': 'company',
#   'datetime': 1698035400,
#   'headline': 'Bitcoin Surges On The Back Of Expected ETF Approval',
#   'id': 123342299,
#   'image': '',
#   'related': 'MS',
#   'source': 'TalkMarkets',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=c2f64784a01b883da96394658866c71b7a1e793c8607610af12661011d530fe9'},
#  {'category': 'company',
#   'datetime': 1698025140,
#   'headline': "Morgan Stanley Investment first adopter of BNY Mellon's new white-labeling service",
#   'id': 123342301,
#   'image': '',
#   'related': 'MS',
#   'source': 'Seeking Alpha',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=b1180842072271eaf544c0670c163a5af9b430d6d78b3d328f1536012089d649'},
#  {'category': 'company',
#   'datetime': 1697962800,
#   'headline': 'ClearBridge Select Strategy Q3 2023 Portfolio Manager Commentary',
#   'id': 123325850,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1002099756/image_1002099756.jpg?io=getty-c-w1536',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': 'The ClearBridge Select Strategy underperformed its Russell 3000 Index benchmark during Q3 2023. Click here to read the full fund letter.',
#   'url': 'https://finnhub.io/api/news?id=be4017f70c75d29c726dc6f68064c0be17a3051cf783b23e4a0e152ad074f04e'},
#  {'category': 'company',
#   'datetime': 1697960521,
#   'headline': 'Dividend Champion, Contender, And Challenger Highlights: Week Of October 22',
#   'id': 123325710,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1072593728/image_1072593728.jpg?io=getty-c-w1536',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': 'A weekly summary of dividend activity for Dividend Champions, Contenders, and Challengers. Click here to read more.',
#   'url': 'https://finnhub.io/api/news?id=38a60e9dc7b11197402f1dc5122645d17314c943214cafab0f87695b96870398'},
#  {'category': 'company',
#   'datetime': 1697944500,
#   'headline': "Headcounts come into focus in banks' Q3 earnings calls",
#   'id': 123329281,
#   'image': '',
#   'related': 'MS',
#   'source': 'Seeking Alpha',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=30facf433089499760572a0d10c2d2b82e88f9fe890f6caf5e98baea6e1d445d'},
#  {'category': 'company',
#   'datetime': 1697832225,
#   'headline': "Goldman Sachs, Bank Of America And Morgan Stanley Continue Last Week's Momentum Of Exceeding Estimates Despite The Macroeconomic Turmoil",
#   'id': 123293210,
#   'image': '',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'This week, The Goldman Sachs Group Inc (NYSE: GS), Bank of America Corporation (NYSE: BAC) and Morgan Stanley (NYSE: MS) joined their big bank peers in releasing their earnings reports, continuing to exceed estimates as banks showed how well they can do even amid challenging times. Despite A Profit Drop And A Messy Quarter, Goldman Sachs Still Exceeded Expectations Goldman Sachs reported its profit dropped 33% to $2.058 billion but earnings per share of $5.47 still topped estimates of $5.31 that',
#   'url': 'https://finnhub.io/api/news?id=ecf6b7309ea177886417ad514a93fb1d6f9005048fa0dddd8073c70b884ac56e'},
#  {'category': 'company',
#   'datetime': 1697819940,
#   'headline': 'Morgan Stanley stock rises Friday, outperforms market',
#   'id': 123307646,
#   'image': 'https://images.mktw.net/im-220105/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'Shares of Morgan Stanley inched 0.29% higher to $73.13 Friday, on what proved to be an all-around poor trading session for the stock market, with the S&P 500...',
#   'url': 'https://finnhub.io/api/news?id=9668322b019f86c424db0f1bfc17b8f967f8bd8621fed595b0f4b02173fa430e'},
#  {'category': 'company',
#   'datetime': 1697816110,
#   'headline': 'Wolfe Research Upgrades Morgan Stanley (MS)',
#   'id': 123284197,
#   'image': '',
#   'related': 'MS',
#   'source': 'Fintel',
#   'summary': '',
#   'url': 'https://finnhub.io/api/news?id=efa068f1efb6e6f549248f592a35bff309a10af075353764492bedfae759063e'},
#  {'category': 'company',
#   'datetime': 1697809026,
#   'headline': "SolarEdge downgraded, Crocs upgraded: Wall Street's top analyst calls",
#   'id': 123284762,
#   'image': 'https://media.zenfs.com/en/the_fly_169/135b0749a3ad5e86fe326a9da1d664b6',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': "Today's top research calls for upgrade, downgrade and initiate on stocks, as compiled by The Fly.",
#   'url': 'https://finnhub.io/api/news?id=7d743a094676990378b65e9536d3df7045f03c638861acdb3f9748ba1ff3b464'},
#  {'category': 'company',
#   'datetime': 1697807531,
#   'headline': 'PJT Partners: A High Quality Company In A Challenging Industry',
#   'id': 123287556,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1446097589/image_1446097589.jpg?io=getty-c-w1536',
#   'related': 'MS',
#   'source': 'SeekingAlpha',
#   'summary': 'PJT Partners, despite operating in a competitive industry, has been able to outperform market indexes and deliver strong results. Learn more on PJT stock here.',
#   'url': 'https://finnhub.io/api/news?id=3ccda4f42b7a1b865b2fbdb9de69c44c4653cb6496dc435a97e83114c7451f20'},
#  {'category': 'company',
#   'datetime': 1697801760,
#   'headline': 'Bull Of The Day: JP Morgan Chase & Co.',
#   'id': 123296872,
#   'image': '',
#   'related': 'MS',
#   'source': 'TalkMarkets',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=e1365871c92b59ff0d9bfbb607d3c76e761312f56db2c7e6a9a9eb313a480cc7'},
#  {'category': 'company',
#   'datetime': 1697800140,
#   'headline': "Hong Kong Stocks End The Week In A Rout As China's Central Bank Pumps $100 Billion Into Banking System Ahead Of Long Weekend",
#   'id': 123286374,
#   'image': '',
#   'related': 'MS',
#   'source': 'Benzinga',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=be16c4c4694814e86d36dc42bb254123c967e3bfd85531b57949e744586dfb61'},
#  {'category': 'company',
#   'datetime': 1697794913,
#   'headline': 'Morgan Stanley (MS) Q3 2023 Earnings: Solid Performance Despite Mixed Market Environment',
#   'id': 123293213,
#   'image': '',
#   'related': 'MS',
#   'source': 'Yahoo',
#   'summary': 'Net Revenues of $13.3 Billion, EPS of $1.38 and ROTCE of 13.5%',
#   'url': 'https://finnhub.io/api/news?id=b88cfdd0bc5bdf062a0ad5073147b312975b4c79efea3505c5eb154a42267b7c'},
#  {'category': 'company',
#   'datetime': 1697794860,
#   'headline': 'Nvidia Gets Another Price-Target Cut. China Restrictions Will Have Consequences, Analyst Says.',
#   'id': 123303978,
#   'image': 'https://images.barrons.com/im-841756/social',
#   'related': 'MS',
#   'source': 'MarketWatch',
#   'summary': 'KeyBanc Capital Markets analyst John Vinh cut lowered his target for the price to $650 from $750.',
#   'url': 'https://finnhub.io/api/news?id=848d5eb71569789c71bd0567993954007bf05d60e6f8cdd3de0edd1b6b6b872e'},
#  {'category': 'company',
#   'datetime': 1697791140,
#   'headline': 'Morgan Stanley upgraded at Wolfe after earnings-induced tumble',
#   'id': 123296944,
#   'image': '',
#   'related': 'MS',
#   'source': 'Seeking Alpha',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=3caf53785a464b6f579b3537fb6e38cbc8878c97aaa7239c6de6300ffb9a7a69'},
#  {'category': 'company',
#   'datetime': 1697786400,
#   'headline': 'Buy AMZN Stock Now, You’ll Never Regret It',
#   'id': 123292061,
#   'image': '',
#   'related': 'MS',
#   'source': 'InvestorPlace',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=644b7830a6155717f296b5932e402d28a6f02d2c75fa5911a5ee189b3a2c6994'},
#  {'category': 'company',
#   'datetime': 1697773980,
#   'headline': 'Morgan Stanley upgraded to Peer Perform from Underperform at Wolfe Research',
#   'id': 123296949,
#   'image': '',
#   'related': 'MS',
#   'source': 'Thefly.com',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=1688e47912bbac5b66dfc5f39cde6d4fb5ff9276613c141200f032104164be28'},
#  {'category': 'company',
#   'datetime': 1697772420,
#   'headline': 'Morgan Stanley (MS) was upgraded to a Hold Rating at Wolfe Research',
#   'id': 123296954,
#   'image': '',
#   'related': 'MS',
#   'source': 'TipRanks',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=2a843297256a46a828986e4670341b468b8ca97612adcd56507c68b453d69768'},
#  {'category': 'company',
#   'datetime': 1697769900,
#   'headline': 'Wolfe Research Upgrades Morgan Stanley (NYSE:MS), says It’s “Fairly Valued”',
#   'id': 123296955,
#   'image': '',
#   'related': 'MS',
#   'source': 'TipRanks',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=ae167c1e642b80b76a6159ec1476a8e90fda07b88dd055d9a80da35a56960bd5'},
#  {'category': 'company',
#   'datetime': 1697768760,
#   'headline': 'You have to neutralize positions when they’re going bad – Virtus’ CMS',
#   'id': 123296884,
#   'image': '',
#   'related': 'MS',
#   'source': 'Seeking Alpha',
#   'summary': 'Looking for stock market analysis and research with proves results? Zacks.com offers in-depth financial research with over 30years of proven results.',
#   'url': 'https://finnhub.io/api/news?id=b7c777bde69e8241148f188a20b64786c2450dc2d51e65927706e9c771cab46b'}]

# %%
len(result)
# Out:
# 198
